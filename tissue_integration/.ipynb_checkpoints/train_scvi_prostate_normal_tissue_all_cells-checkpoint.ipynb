# %%
import scvi
import scanpy as sc
import pandas as pd
import numpy as np
# Out:
# Global seed set to 0
# /itf-fi-ml/home/hermankn/.local/lib/python3.8/site-packages/pytorch_lightning/utilities/warnings.py:53: LightningDeprecationWarning: pytorch_lightning.utilities.warnings.rank_zero_deprecation has been deprecated in v1.6 and will be removed in v1.8. Use the equivalent function from the pytorch_lightning.utilities.rank_zero module instead.
#   new_rank_zero_deprecation(
# /itf-fi-ml/home/hermankn/.local/lib/python3.8/site-packages/pytorch_lightning/utilities/warnings.py:58: LightningDeprecationWarning: The `pytorch_lightning.loggers.base.rank_zero_experiment` is deprecated in v1.7 and will be removed in v1.9. Please use `pytorch_lightning.loggers.logger.rank_zero_experiment` instead.
#   return new_rank_zero_deprecation(*args, **kwargs)

# %%
import matplotlib.pyplot as plt

# %%
import scanpy.external as sce

# %%
import torch
import pickle

# %%
import anndata

# %%
import h5py

# %%
from pyscenic.aucell import aucell
from pyscenic.genesig import GeneSignature
from pyscenic.aucell import create_rankings, enrichment

# %% [markdown]
# #### Load data

# %%
adata = sc.read('prostate_normal.h5ad')

# %% [markdown]
# #### QC

# %%
adata.var['mt'] = adata.var_names.str.startswith('MT-')  # annotate mitochondrial genes as 'mt'
adata.var['ribo'] = adata.var_names.str.startswith(("RPS","RPL")) # annotate ribosomal genes as 'ribo'
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt', 'ribo'], percent_top=None, log1p=False, inplace=True)

# %%
adata = adata[adata.obs.total_counts > 300, :]
adata = adata[adata.obs.pct_counts_mt < 20, :]
adata = adata[adata.obs.total_counts < 40000, :]

# %% [markdown]
# #### Train model

# %%
scvi.model.SCVI.setup_anndata(adata, batch_key="batch", labels_key='tuong_immune_cell_type')

# %%
vae = scvi.model.SCVI(adata, n_layers=2, n_latent=30, gene_likelihood="nb")

# %%
vae.train()
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Epoch 386/386: 100%|██████████| 386/386 [19:06<00:00,  3.00s/it, loss=3.92e+03, v_num=1]
# `Trainer.fit` stopped: `max_epochs=386` reached.
# Epoch 386/386: 100%|██████████| 386/386 [19:06<00:00,  2.97s/it, loss=3.92e+03, v_num=1]

# %%
plt.plot(vae.history["elbo_train"], label="train")
#plt.plot(vae.history["elbo_validation"], label="val")
plt.title("Negative ELBO over training epochs")
#plt.ylim(1100, 1500)
plt.legend()

# %%
lvae = scvi.model.SCANVI.from_scvi_model(
    vae,
    adata=adata,
    unlabeled_category="Unknown",
)

# %%
lvae.train(200)
# Out:
# INFO     Training for 200 epochs.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Epoch 200/200: 100%|██████████| 200/200 [24:26<00:00,  7.08s/it, loss=3.83e+03, v_num=1]
# `Trainer.fit` stopped: `max_epochs=200` reached.
# Epoch 200/200: 100%|██████████| 200/200 [24:26<00:00,  7.33s/it, loss=3.83e+03, v_num=1]

# %%
plt.plot(lvae.history["elbo_train"], label="train")
#plt.plot(vae.history["elbo_validation"], label="val")
plt.title("Negative ELBO over training epochs")
#plt.ylim(1100, 1500)
plt.legend()

# %%
adata.obsm["X_scVI"] = vae.get_latent_representation(adata)

# %%
adata.obsm["X_scANVI"] = lvae.get_latent_representation(adata)

# %%
sc.pp.neighbors(adata, use_rep="X_scVI")
sc.tl.umap(adata)

# %%
adata.obs["C_scANVI"] = lvae.predict(adata)

# %%
sc.pp.neighbors(adata, use_rep="X_scANVI")
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color='C_scANVI')

# %%
adata_celltypist = adata.copy()

# %%
import celltypist

# %%
sc.pp.normalize_total(adata_celltypist, target_sum=1e4)
sc.pp.log1p(adata_celltypist)

# %%
predictions = celltypist.annotate(adata_celltypist, model = 'Immune_All_Low.pkl', majority_voting = True)

# %%
adata.obs['celltypist_prediction'] = predictions.predicted_labels['predicted_labels'][adata.obs.index]#.to_numpy()
adata.obs['celltypist_majority_voting'] = predictions.predicted_labels['majority_voting'][adata.obs.index]#.to_numpy()

# %%
sc.tl.leiden(adata, resolution=0.5)

# %%
adata.obs['level2_cell_type'] = adata.obs['C_scANVI']

# %%
adata.obs['level2_cell_type'] = [x if x in ['BE', 'CE', 'Endothelial', 'LE-KLK3', 'LE-KLK4', 'Sperm'] else y for x,y in zip(adata.obs['level2_cell_type'], adata.obs['celltypist_majority_voting'])]

# %%
sc.pl.umap(adata, color='level2_cell_type')#, groups=['DC1'])#, groups='LE-KLK4')

# %%
level2_level1_dict = {'CD16+ NK cells' : 'Lymphoid', 'CD16- NK cells' : 'Lymphoid', 'CE' : 'Epithelial cells', 'Classical monocytes' : 'Myeloid', 'DC' : 'Myeloid', 'DC1' : 'Myeloid',
       'Endothelial' : 'Mesenchymal', 'Epithelial cells' : 'Epithelial cells', 'ILC' : 'Lymphoid', 'LE-KLK3' : 'Epithelial cells', 'LE-KLK4' : 'Epithelial cells',
       'Macrophages' : 'Myeloid', 'Mast cells' : 'Lymphoid', 'Memory B cells' : 'Lymphoid',
       'Non-classical monocytes' : 'Myeloid', 'Plasma cells' : 'Lymphoid', 'Regulatory T cells' : 'Lymphoid',
       'Tcm/Naive helper T cells' : 'Lymphoid', 'Tem/Effector helper T cells' : 'Lymphoid',
       'Tem/Trm cytotoxic T cells' : 'Lymphoid', 'Type 1 helper T cells' : 'Lymphoid',
       'Type 17 helper T cells' : 'Lymphoid', 'pDC' : 'Lymphoid', 'Tem/Temra cytotoxic T cells' : 'Lymphoid', 'BE' : 'Epithelial cells', 'MAIT cells' : 'Lymphoid', 'Sperm' : 'Sperm', 'Monocytes' : 'Myeloid', 'Fibroblasts' : 'Mesenchymal',
                     'Late erythroid' : 'Erythroid'}

# %%
adata.obs['level1_cell_type'] = [level2_level1_dict[x] for x in adata.obs['level2_cell_type']]

# %%
sc.pl.umap(adata, color='level1_cell_type')

# %%
lvae.save('prostate_normal_tissue_all_cells_scanvi', overwrite=True)

# %%
adata.write('prostate_normal.h5ad')
