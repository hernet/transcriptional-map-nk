# %%
import scanpy as sc

# %%
import pandas as pd
import numpy as np
import loompy as lp
# Out:
# /home/ubuntu/miniconda3/envs/scenic/lib/python3.9/site-packages/loompy/bus_file.py:68: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def twobit_to_dna(twobit: int, size: int) -> str:
# /home/ubuntu/miniconda3/envs/scenic/lib/python3.9/site-packages/loompy/bus_file.py:85: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def dna_to_twobit(dna: str) -> int:
# ...

# %%
import os

# %%
import matplotlib.pyplot as plt

# %%
adata = sc.read('all_nk_cells.h5ad')

# %%
sc.pp.log1p(adata)

# %%
#!wget -nc https://raw.githubusercontent.com/aertslab/SCENICprotocol/master/example/allTFs_hg38.txt

# %%
tfs_path = "allTFs_hg38.txt"

# %%
tfs = [tf.strip() for tf in open(tfs_path)]

# %%
adata_batch = adata #rna

# %%
print(
    f"%{np.sum(adata_batch.var.index.isin(tfs))} out of {len(tfs)} TFs are found in the object"
)
# Out:
# %1251 out of 1797 TFs are found in the object

# %%
#row_attributes = {
#    "Gene": np.array(adata_batch.var.index),
#}
#col_attributes = {
#    "CellID": np.array(adata_batch.obs.index),
#    "nGene": np.array(np.sum(adata_batch.X.transpose() > 0, axis=0)).flatten(),
#    "nUMI": np.array(np.sum(adata_batch.X.transpose(), axis=0)).flatten(),
#}

#lp.create(loom_path, adata_batch.X.transpose(), row_attributes, col_attributes)

# %%
num_workers = 20

# %%
outpath_adj = "adj_filtered.csv"
if not os.path.exists(outpath_adj):
    # !pyscenic grn {loom_path} {tfs_path} -o $outpath_adj --num_workers {num_workers}

# %%
results_adjacencies = pd.read_csv(outpath_adj, index_col=False, sep=",")
print(f"Number of associations: {results_adjacencies.shape[0]}")
results_adjacencies.head()
# Out:
# Number of associations: 5094212
#         TF  target  importance
# 0  HNRNPA1  EEF1A1  973.545587
# 1    EEF1D  EEF1A1  763.843893
# 2  HNRNPA1     B2M  720.296865
# 3      FOS   DUSP1  516.447921
# 4    EEF1D     B2M  510.790527

# %%
plt.hist(np.log10(results_adjacencies["importance"]), bins=50)
plt.xlim([-10, 10])
# Out:
# (-10.0, 10.0)

# %%
#!wget -nc https://resources.aertslab.org/cistarget/databases/homo_sapiens/hg38/refseq_r80/mc9nr/gene_based/hg38__refseq-r80__10kb_up_and_down_tss.mc9nr.genes_vs_motifs.rankings.feather

# %%
import glob
import os

# ranking databases
db_glob = "/tumor-data/*feather"
db_names = " ".join(glob.glob(db_glob))

# %%
db_names
# Out:
# '/tumor-data/hg38__refseq-r80__10kb_up_and_down_tss.mc9nr.genes_vs_motifs.rankings.feather'

# %%
#!wget -nc https://resources.aertslab.org/cistarget/motif2tf/motifs-v9-nr.hgnc-m0.001-o0.0.tbl

# %%
# motif databases
motif_path = "/tumor-data/motifs-v9-nr.hgnc-m0.001-o0.0.tbl"

# %%
if not os.path.exists('/tumor-data/reg_after_filter_3.csv'):
    # !pyscenic ctx /tumor-data/adj_filtered.csv \
        {db_names} \
        --annotations_fname {motif_path} \
        --expression_mtx_fname {loom_path} \
        --output /tumor-data/reg_after_filter_3.csv \
        --mask_dropouts \
        --num_workers {num_workers} > pyscenic_ctx_stdout.txt

# %%
import numpy as np

n_genes_detected_per_cell = np.sum(adata_batch.X > 0, axis=1)
percentiles = pd.Series(n_genes_detected_per_cell.flatten().A.flatten()).quantile(
    [0.01, 0.05, 0.10, 0.50, 1]
)
print(percentiles)
# Out:
# 0.01     229.0
# 0.05     307.0
# 0.10     373.0
# 0.50     707.0
# 1.00    5475.0
# dtype: float64

# %%
import numpy as np

n_genes_detected_per_cell = np.sum(adata_batch.X > 0, axis=1)
percentiles = pd.Series(n_genes_detected_per_cell.flatten().A.flatten()).quantile(
    [0.01, 0.05, 0.10, 0.50, 1]
)
print(percentiles)
# Out:
# 0.01     229.0
# 0.05     307.0
# 0.10     373.0
# 0.50     707.0
# 1.00    5475.0
# dtype: float64

# %%
import seaborn as sns

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5), dpi=100)
sns.distplot(n_genes_detected_per_cell, norm_hist=False, kde=False, bins="fd")
for i, x in enumerate(percentiles):
    fig.gca().axvline(x=x, ymin=0, ymax=1, color="red")
    ax.text(
        x=x,
        y=ax.get_ylim()[1],
        s=f"{int(x)} ({percentiles.index.values[i]*100}%)",
        color="red",
        rotation=30,
        size="x-small",
        rotation_mode="anchor",
    )
ax.set_xlabel("# of genes")
ax.set_ylabel("# of cells")
fig.tight_layout()
# Out:
# /tmp/ipykernel_656939/1384461256.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(n_genes_detected_per_cell, norm_hist=False, kde=False, bins="fd")

# %%
loom_path_output = 'all_nk_output.loom'

# %%
if not os.path.exists(loom_path_output):
    # !pyscenic aucell /tumor-data/adata_all_nk_input_filtered.loom \
        /tumor-data/reg_trend_restricted.csv \
        --output /tumor-data/adata_all_nk_output_filtered_trends.loom \
        --num_workers 5 > pyscenic_aucell_stdout.txt
# Out:
# /home/ubuntu/miniconda3/envs/scenic/lib/python3.9/site-packages/loompy/bus_file.py:68: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def twobit_to_dna(twobit: int, size: int) -> str:
# /home/ubuntu/miniconda3/envs/scenic/lib/python3.9/site-packages/loompy/bus_file.py:85: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def dna_to_twobit(dna: str) -> int:
# ...

# %%
import json
import zlib
import base64

# collect SCENIC AUCell output
lf = lp.connect(loom_path_output, mode="r+", validate=False)
auc_mtx = pd.DataFrame(lf.ca.RegulonsAUC, index=lf.ca.CellID)
lf.close()

# %%
import anndata as ad

ad_auc_mtx = ad.AnnData(auc_mtx)

# %%
ad_auc_mtx
# Out:
# AnnData object with n_obs × n_vars = 89604 × 330

# %%
nk_data_all_df = pd.read_excel('/tumor-data/NK_data_all_experiments.xlsx', sheet_name=4, index_col=0, header=[0,1,2,3])
# Out:
# /home/ubuntu/miniconda3/envs/scenic/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
nk_data_all_df.columns[[33 in x for x in nk_data_all_df.columns]]
# Out:
# MultiIndex([('L354_A01', 'Activ KIR+ expsn', 33,               '1-CD56bright'),
#             ('L354_G01', 'Activ KIR+ expsn', 33,               '1-CD56bright'),
#             ('L354_G02', 'Activ KIR+ expsn', 33,               '1-CD56bright'),
#             ('L354_A02', 'Activ KIR+ expsn', 33,        '2-CD56dimNKG2A+KIR-'),
#             ('L354_G03', 'Activ KIR+ expsn', 33,        '2-CD56dimNKG2A+KIR-'),
#             ('L354_A03', 'Activ KIR+ expsn', 33,        '3-CD56dimNKG2A+KIR+'),
#             ('L354_G04', 'Activ KIR+ expsn', 33,        '3-CD56dimNKG2A+KIR+'),
#             ('L354_A04', 'Activ KIR+ expsn', 33,        '4-CD56dimNKG2A-KIR+'),
#             ('L354_A05', 'Activ KIR+ expsn', 33, '5-CD56dimNKG2A-NKG2C-aKIR+'),
#             ('L354_G05', 'Activ KIR+ expsn', 33, '5-CD56dimNKG2A-NKG2C-aKIR+'),
#             ('L354_A06', 'Activ KIR+ expsn', 33,        '6-CD56dimNKG2A-KIR-'),
#             ('L354_G06', 'Activ KIR+ expsn', 33,        '6-CD56dimNKG2A-KIR-')],
# ...

# %%
np.mean(nk_data_all_df.loc['NCAM1'][nk_data_all_df.columns[[33 in x for x in nk_data_all_df.columns]]][:3])
# Out:
# 494.0125166386124

# %%
nk_data_all_mean = nk_data_all_df.T.groupby(['Patient', 'Cell Popul']).mean().copy()

# %%
nk_data_all_mean_cell_pop = nk_data_all_df.T.groupby(['Cell Popul']).mean().copy()

# %%
genes_not_in = [x for x in adata_batch.var_names if x not in nk_data_all_mean_cell_pop.columns]

# %%
genes_in = [x for x in adata_batch.var_names if x in nk_data_all_mean_cell_pop.columns]

# %%
genes_after_filter_bulk = nk_data_all_mean_cell_pop[genes_in].columns[np.array(np.max(nk_data_all_mean_cell_pop[genes_in]) > 2)]
# Out:
# /home/ubuntu/miniconda3/envs/scenic/lib/python3.9/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.max(axis=None) will return a scalar max over the entire DataFrame. To retain the old behavior, use 'frame.max(axis=0)' or just 'frame.max()'
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
genes_after_filter_bulk
# Out:
# Index(['LINC00115', 'NOC2L', 'KLHL17', 'ISG15', 'TNFRSF18', 'TNFRSF4', 'SDF4',
#        'B3GALT6', 'UBE2J2', 'SCNN1D',
#        ...
#        'COL18A1', 'COL6A1', 'COL6A2', 'LSS', 'MCM3AP', 'YBEY', 'PCNT', 'DIP2A',
#        'S100B', 'PRMT2'],
#       dtype='object', length=9553)

# %%
mp_genes_in = sc.pl.matrixplot(adata_batch, var_names=genes_in, groupby='subset_only', return_fig=True)

# %%
mp_genes_in.values_df[[x[0] == 't' for x in mp_genes_in.values_df.index]]
# Out:
#                    LINC00115    SAMD11     NOC2L    KLHL17   PLEKHN1  \
# subset_only
# tissue CD56bright   0.004255  0.000000  0.074960  0.000489  0.006320
# tissue CD56dim      0.006220  0.000213  0.075557  0.003828  0.001196
# tumor CD56bright    0.006624  0.000478  0.068597  0.003224  0.008597
# tumor CD56dim       0.004791  0.000672  0.058478  0.003477  0.001736
#
#                        HES4     ISG15      AGRN  TNFRSF18   TNFRSF4  ...  \
# subset_only                                                          ...
# tissue CD56bright  0.026228  0.251229  0.002444  0.257603  0.072794  ...
# tissue CD56dim     0.028896  0.283042  0.002632  0.109780  0.036493  ...
# tumor CD56bright   0.025874  0.455383  0.006527  0.477794  0.083329  ...
# tumor CD56dim      0.027069  0.282331  0.003499  0.099683  0.043075  ...
#
#                       PCBP3    COL6A1    COL6A2       LSS    MCM3AP      YBEY  \
# subset_only
# ...

# %%
genes_in_filter_tumor_tissue = mp_genes_in.values_df.columns[mp_genes_in.values_df[[x[0] == 't' for x in mp_genes_in.values_df.index]].mean(axis=0) > 0.01]
genes_in_filter_tumor_tissue = [x for x in genes_in_filter_tumor_tissue if x not in genes_after_filter_bulk]

# %%
mp = sc.pl.matrixplot(adata_batch, var_names=genes_not_in, groupby='subset_only', return_fig=True)

# %%
gene_after_filter_not_bulk = mp.values_df.columns[mp.values_df.mean(axis=0) > 0.01]

# %%
auc_mtx = auc_mtx.loc[:,[x[:-3] in all_genes for x in auc_mtx.columns]].copy()

# %%
adata_batch.obs[auc_mtx.columns] = auc_mtx
# Out:
# /tmp/ipykernel_439055/3754354685.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   adata_batch.obs[auc_mtx.columns] = auc_mtx
# /tmp/ipykernel_439055/3754354685.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   adata_batch.obs[auc_mtx.columns] = auc_mtx
# ...

# %%
auc_mtx["subset_source"] = adata_batch.obs["subset_source"]

# %%
auc_mtx["low_res_subset"] = adata_batch.obs["low_res_subset"]
mean_auc_by_cell_type = auc_mtx.groupby("low_res_subset").mean()
# Out:
# /tmp/ipykernel_439055/749943975.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mean_auc_by_cell_type = auc_mtx.groupby("low_res_subset").mean()

# %%
sc.pl.matrixplot(adata_batch_milo, top_tfs_groups, 
                 groupby='nhood_group', standard_scale='var', save='top_tfs_diff_between_nhood_groups.pdf')
# Out:
# WARNING: saving figure to file matrixplot_top_tfs_diff_between_nhood_groups.pdf

# %%
sc.pl.matrixplot(adata_batch_milo, tfs_pb_nk_df.index, 
                 groupby='nhood_group', standard_scale='var', save='top_tfs_diff_nhood_groups_sorted_by_group_exp.pdf')
# Out:
# WARNING: saving figure to file matrixplot_top_tfs_diff_nhood_groups_sorted_by_group_exp.pdf

# %% [markdown]
# ### PB NK temporal

# %%
adata_blood_all = sc.read('pb_12_donors_pseudotime.h5ad')

# %%
ad_auc_mtx = ad.AnnData(auc_mtx)

# %%
pb_auc_mtx = ad_auc_mtx[adata_blood_all.obs_names].copy()

# %%
pb_auc_mtx.obs['pseudotime'] = adata_blood_all.obs['pseudotime']

# %%
import pickle
pr_res = pickle.load(open('pr_res.pkl', 'rb'))
# Out:
# findfont: Font family ['Raleway'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Lato'] not found. Falling back to DejaVu Sans.

# %%
norm_pseudotime = pr_res.pseudotime.sort_values().copy(0)

# %%
for i, barcode in enumerate(norm_pseudotime.index):
    norm_pseudotime[barcode] = i/(len(norm_pseudotime)-1)

# %%
pr_res._pseudotime = norm_pseudotime

# %%
tf_df = pb_auc_mtx.to_df()

# %%
dm_res = pickle.load( open( "dm_res.pkl", "rb" ) )

# %%
tf_df.index = dm_res['EigenVectors'].index

# %%
import palantir

# %%
import matplotlib.pyplot as plt

# %%
sc.set_figure_params(scanpy=True, dpi=80, dpi_save=150, frameon=True, vector_friendly=True, 
                         fontsize=14, figsize=(10,10), color_map=None, format='pdf', facecolor=None, 
                     transparent=False, ipython_format='png2x')

# %%
gene_trends = palantir.presults.compute_gene_trends(pr_res, tf_df)

# %%
gene_trends['CD57+'] = gene_trends[13850]

# %%
gene_trends['Adaptive'] = gene_trends[10017]

# %%
del gene_trends[13850]
del gene_trends[10017]

# %%
plot_gene_trends(gene_trends, genes=tfs_pb_nk)
plt.savefig('regulon_activity_trends_pseudotime_restricted_to_trends.pdf')
