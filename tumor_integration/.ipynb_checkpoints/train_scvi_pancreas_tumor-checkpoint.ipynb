# %%
import scvi
import scanpy as sc
import pandas as pd
import numpy as np
# Out:
# Global seed set to 0

# %%
import matplotlib.pyplot as plt

# %%
import scanpy.external as sce

# %%
import torch
import pickle

# %%
import anndata

# %%
import h5py

# %%
import os

# %%
from pyscenic.aucell import aucell
from pyscenic.genesig import GeneSignature
from pyscenic.aucell import create_rankings, enrichment

# %% [markdown]
# #### Load data

# %%
adata = sc.read('pancreas_tumor.h5ad')
# Out:
# /itf-fi-ml/home/hermankn/.local/lib/python3.8/site-packages/anndata/_core/anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %% [markdown]
# #### QC

# %%
adata.var['mt'] = adata.var_names.str.startswith('MT-')  # annotate mitochondrial genes as 'mt'
adata.var['ribo'] = adata.var_names.str.startswith(("RPS","RPL")) # annotate ribosomal genes as 'ribo'
sc.pp.calculate_qc_metrics(adata, percent_top=None, log1p=False, inplace=True, qc_vars=['mt', 'ribo'])

# %%
adata = adata[adata.obs.total_counts > 300, :]
adata = adata[adata.obs.pct_counts_mt < 20, :]
adata = adata[adata.obs.total_counts < 40000, :]

# %% [markdown]
# #### Train model

# %%
adata = adata.copy()
# Out:
# /itf-fi-ml/home/hermankn/.local/lib/python3.8/site-packages/anndata/_core/anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
scvi.model.SCVI.setup_anndata(adata, batch_key="batch", labels_key='fine_peng_cell_type')

# %%
vae = scvi.model.SCVI(adata, n_layers=2, n_latent=30, gene_likelihood="nb")

# %%
vae.train()
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Epoch 64/64: 100%|██████████| 64/64 [13:09<00:00, 12.34s/it, loss=5.96e+03, v_num=1]

# %%
plt.plot(vae.history["elbo_train"], label="train")
#plt.plot(vae.history["elbo_validation"], label="val")
plt.title("Negative ELBO over training epochs")
#plt.ylim(1100, 1500)
plt.legend()

# %%
lvae = scvi.model.SCANVI.from_scvi_model(
    vae,
    adata=adata,
    unlabeled_category="Unknown",
)

# %%
lvae.train(25)
# Out:
# INFO     Training for 25 epochs.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Epoch 25/25: 100%|██████████| 25/25 [10:50<00:00, 26.01s/it, loss=6.09e+03, v_num=1]

# %%
plt.plot(lvae.history["elbo_train"], label="train")
#plt.plot(vae.history["elbo_validation"], label="val")
plt.title("Negative ELBO over training epochs")
#plt.ylim(1100, 1500)
plt.legend()

# %%
adata.obsm["X_scVI"] = vae.get_latent_representation(adata)

# %%
adata.obsm["X_scANVI"] = lvae.get_latent_representation(adata)

# %%
sc.pp.neighbors(adata, use_rep="X_scVI")
sc.tl.umap(adata)

# %%
lvae.save('pancreas_tumor_all_cells_scanvi_model', overwrite=True)

# %%
adata.obs["C_scANVI"] = lvae.predict(adata)

# %%
sc.pp.neighbors(adata, use_rep="X_scANVI")
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color=['C_scANVI'])
# Out:
# WARNING: saving figure to file /itf-fi-ml/home/hermankn/research_folder/figures/tumor_pancreas_all_cells_figs/umappredication_major_cell_types_scanvi.pdf

# %%
adata_immune = adata[adata.obs['level1_cell_type'].isin(['Lymphoid', 'Myeloid'])].copy()

# %% [markdown]
# ### Immune only

# %%
scvi.model.SCVI.setup_anndata(adata_immune, batch_key="batch")

# %%
vae = scvi.model.SCVI(adata_immune, n_layers=2, n_latent=30, gene_likelihood="nb")

# %%
vae.train()
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Epoch 245/245: 100%|██████████| 245/245 [12:10<00:00,  2.98s/it, loss=4.18e+03, v_num=1]

# %%
plt.plot(vae.history["elbo_train"], label="train")
#plt.plot(vae.history["elbo_validation"], label="val")
plt.title("Negative ELBO over training epochs")
#plt.ylim(1100, 1500)
plt.legend()

# %%
lvae = scvi.model.SCANVI.from_scvi_model(
    vae,
    adata=adata_immune,
    unlabeled_category="Unknown",
)
# Out:
# /itf-fi-ml/home/hermankn/.local/lib/python3.8/site-packages/scvi/data/fields/_layer_field.py:78: UserWarning: adata.X does not contain unnormalized count data. Are you sure this is what you want?
#   warnings.warn(

# %%
lvae.train(25)
# Out:
# INFO     Training for 25 epochs.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Epoch 25/25: 100%|██████████| 25/25 [16:10<00:00, 38.83s/it, loss=2.68e+03, v_num=1]

# %%
plt.plot(lvae.history["elbo_train"], label="train")
#plt.plot(vae.history["elbo_validation"], label="val")
plt.title("Negative ELBO over training epochs")
#plt.ylim(1100, 1500)
plt.legend()

# %%
adata_immune.obsm["X_scVI"] = vae.get_latent_representation(adata_immune)

# %%
adata_immune.obsm["X_scANVI"] = lvae.get_latent_representation(adata_immune)

# %%
sc.pp.neighbors(adata_immune, use_rep="X_scVI")
sc.tl.umap(adata_immune)

# %% [markdown]
# #### Celltypist predication

# %%
import celltypist

# %%
adata_celltypist = adata_immune.copy()

# %%
sc.pp.normalize_total(adata_celltypist, target_sum=1e4)
sc.pp.log1p(adata_celltypist)

# %%
predictions = celltypist.annotate(adata_celltypist, model = 'Immune_All_Low.pkl', majority_voting = True)

# %%
adata_immune.obs['celltypist_prediction'] = predictions.predicted_labels['predicted_labels'][adata_immune.obs.index]#.to_numpy()
adata_immune.obs['celltypist_majority_voting'] = predictions.predicted_labels['majority_voting'][adata_immune.obs.index]#.to_numpy()

# %%
adata.obs['level2_cell_type'] = [adata_immune.obs['celltypist_majority_voting'][y] if y in adata_immune.obs.index else x for x,y in zip(adata.obs['C_scANVI'], adata.obs.index)]

# %% [markdown]
# #### Sankey

# %%
level1_level2_df = sc.get.obs_df(adata,keys=['level1_cell_type', 'level2_cell_type'])
level1_level2_df = pd.crosstab(level1_level2_df['level1_cell_type'], level1_level2_df['level2_cell_type']).T

# %%
level2_color_dict = dict(np.array([adata.obs['level2_cell_type'].cat.categories, adata.uns['level2_cell_type_colors']]).T)

# %%
level1_color_dict = dict(np.array([adata.obs['level1_cell_type'].cat.categories, adata.uns['level1_cell_type_colors']]).T)

# %%
from utils.sankey_diagram import sankey_diagram

# %%
np.unique(adata.obs['level1_cell_type'])
# Out:
# array(['Endocrine', 'Epithelial', 'Exocrine', 'Lymphoid', 'Mesenchymal',
#        'Myeloid'], dtype=object)

# %%
order_cell_types = ['Endocrine', 'Epithelial', 'Exocrine', 'Mesenchymal','Myeloid', 'Lymphoid']

# %%
level1_level2_df = level1_level2_df[order_cell_types]

# %%
a_sort = list(np.flip(order_cell_types))

# %%
sankey_diagram(adata.obs[['level1_cell_type', 'level2_cell_type']].to_numpy(), level1_color_dict, level2_color_dict, a_sort=a_sort, b_sort=b_sort, figsize=(8,12), save_path=os.path.join(figures_dir, 'sankey_level1_level2.pdf'))
# Out:
# /itf-fi-ml/home/hermankn/notebooks/utils/_alluvial.py:156: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(alluvial_fan)
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %%
sankey_diagram(adata.obs[['level1_cell_type', 'level2_cell_type']].to_numpy(), level1_color_dict, level2_color_dict, a_sort=a_sort, b_sort=b_sort, figsize=(8,12), show=True)
# Out:
# /itf-fi-ml/home/hermankn/notebooks/utils/_alluvial.py:156: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(alluvial_fan)
