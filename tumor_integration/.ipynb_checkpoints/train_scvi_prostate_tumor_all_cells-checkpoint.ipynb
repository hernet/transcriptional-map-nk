# %%
import scvi
import scanpy as sc
import pandas as pd
import numpy as np
# Out:
# Global seed set to 0

# %%
import matplotlib.pyplot as plt

# %%
import scanpy.external as sce

# %%
import torch
import pickle

# %%
from pyscenic.aucell import aucell
from pyscenic.genesig import GeneSignature
from pyscenic.aucell import create_rankings, enrichment

# %% [markdown]
# #### Load data

# %%
adata = sc.read('prostate_tumor.h5ad')

# %% [markdown]
# #### QC

# %%
adata.var['mt'] = adata.var_names.str.startswith('MT-')  # annotate mitochondrial genes as 'mt'
adata.var['ribo'] = adata.var_names.str.startswith(("RPS","RPL")) # annotate ribosomal genes as 'ribo'
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt', 'ribo'], percent_top=None, log1p=False, inplace=True)

# %%
adata = adata[adata.obs.total_counts > 300, :]
adata = adata[adata.obs.pct_counts_mt < 20, :]
adata = adata[adata.obs.total_counts < 40000, :]

# %% [markdown]
# #### Train model

# %%
scvi.model.SCVI.setup_anndata(adata, batch_key="batch", labels_key='tuong_immune_cell_type')

# %%
vae = scvi.model.SCVI(adata, n_layers=2, n_latent=30, gene_likelihood="nb")

# %%
vae.train()
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Epoch 126/126: 100%|██████████| 126/126 [13:47<00:00,  6.57s/it, loss=5.05e+03, v_num=1]

# %%
plt.plot(vae.history["elbo_train"], label="train")
#plt.plot(vae.history["elbo_validation"], label="val")
plt.title("Negative ELBO over training epochs")
#plt.ylim(1100, 1500)
plt.legend()

# %%
lvae = scvi.model.SCANVI.from_scvi_model(
    vae,
    adata=adata,
    unlabeled_category="Unknown",
)

# %%
lvae.train(25)
# Out:
# INFO     Training for 25 epochs.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Epoch 25/25: 100%|██████████| 25/25 [05:24<00:00, 13.00s/it, loss=5.14e+03, v_num=1]

# %%
plt.plot(lvae.history["elbo_train"], label="train")
#plt.plot(vae.history["elbo_validation"], label="val")
plt.title("Negative ELBO over training epochs")
#plt.ylim(1100, 1500)
plt.legend()

# %%
adata.obsm["X_scVI"] = vae.get_latent_representation(adata)
# Out:
# Epoch 1/126:   0%|          | 0/126 [20:46<?, ?it/s]

# %%
adata.obsm["X_scANVI"] = lvae.get_latent_representation(adata)

# %%
adata.obs["C_scANVI"] = lvae.predict(adata)

# %%
np.unique(adata.obs['C_scANVI'])
# Out:
# array(['B cell', 'CD4 naive-cm', 'CD8 Trm', 'CE', 'DC', 'Endothelial',
#        'LE-KLK3', 'LE-KLK4', 'Mac1', 'Mast cell', 'Mono', 'NK CD16pos',
#        'T cell'], dtype=object)

# %%
adata_immune = adata[adata.obs['C_scANVI'].isin(['B cell', 'T cell' , 'NK CD16pos', 'Mast cell', 'DC', 'CD8 Trm', 'CD4 naive-cm', 'Mac1', 'Mono'])].copy()

# %%
lvae.save('prostate_tumor_all_cells_scanvi', overwrite=True)

# %%
sc.pl.umap(adata, color='level2_cell_type')

# %%
level2_level1_dict = {'CD16+ NK cells' : 'Lymphoid', 'CD16- NK cells' : 'Lymphoid', 'CE' : 'Epithelial cells', 'Classical monocytes' : 'Myeloid', 'DC' : 'Myeloid',
       'Endothelial' : 'Mesenchymal', 'Epithelial cells' : 'Epithelial cells', 'ILC' : 'Lymphoid', 'LE-KLK3' : 'Epithelial cells', 'LE-KLK4' : 'Epithelial cells',
       'Macrophages' : 'Myeloid', 'Mast cells' : 'Lymphoid', 'Memory B cells' : 'Lymphoid',
       'Non-classical monocytes' : 'Myeloid', 'Plasma cells' : 'Lymphoid', 'Regulatory T cells' : 'Lymphoid',
       'Tcm/Naive helper T cells' : 'Lymphoid', 'Tem/Effector helper T cells' : 'Lymphoid',
       'Tem/Trm cytotoxic T cells' : 'Lymphoid', 'Type 1 helper T cells' : 'Lymphoid',
       'Type 17 helper T cells' : 'Lymphoid', 'pDC' : 'Lymphoid'}

# %%
adata.obs['level1_cell_type'] = [level2_level1_dict[x] for x in adata.obs['level2_cell_type']]

# %% [markdown]
# #### Celltypist

# %%
adata_celltypist = adata_immune.copy()

# %%
import celltypist

# %%
sc.pp.normalize_total(adata_celltypist, target_sum=1e4)
sc.pp.log1p(adata_celltypist)

# %%
predictions = celltypist.annotate(adata_celltypist, model = 'Immune_All_Low.pkl', majority_voting = True)

# %%
adata_immune.obs['celltypist_prediction'] = predictions.predicted_labels['predicted_labels'][adata_immune.obs.index]#.to_numpy()
adata_immune.obs['celltypist_majority_voting'] = predictions.predicted_labels['majority_voting'][adata_immune.obs.index]#.to_numpy()

# %%
adata.obs['level2_cell_type'] = [adata_immune.obs.loc[x]['celltypist_majority_voting'] if x in adata_immune.obs.index else leiden_type_dict[y] for x,y in zip(adata.obs.index, adata.obs['leiden'])]

# %%
sc.pl.umap(adata, color='level1_cell_type', save='prostate_level1_annotation.pdf')
# Out:
# WARNING: saving figure to file /itf-fi-ml/home/hermankn/uio_research/figures/prostate_tumor_all_cells_figs/umapprostate_level1_annotation.pdf

# %% [markdown]
# #### Sankey

# %%
level1_level2_df = sc.get.obs_df(adata,keys=['level1_cell_type', 'level2_cell_type'])
level1_level2_df = pd.crosstab(level1_level2_df['level1_cell_type'], level1_level2_df['level2_cell_type']).T

# %%
level2_color_dict = dict(np.array([adata.obs['level2_cell_type'].cat.categories, adata.uns['level2_cell_type_colors']]).T)

# %%
level1_color_dict = dict(np.array([adata.obs['level1_cell_type'].cat.categories, adata.uns['level1_cell_type_colors']]).T)

# %%
from utils.sankey_diagram import sankey_diagram

# %%
order_cell_types = ['Epithelial cells', 'Mesenchymal', 'Myeloid', 'Lymphoid']

# %%
level1_level2_df = level1_level2_df[order_cell_types]

# %%
a_sort = list(np.flip(order_cell_types))

# %%
sankey_diagram(adata.obs[['level1_cell_type', 'level2_cell_type']].to_numpy(), level1_color_dict, level2_color_dict, figsize=(8,12), a_sort=a_sort, b_sort=b_sort, save_path=os.path.join(figures_dir, 'sankey_level1_level2.pdf'))

# %%
sankey_diagram(adata.obs[['level1_cell_type', 'level2_cell_type']].to_numpy(), level1_color_dict, level2_color_dict, a_sort=a_sort, figsize=(8,12), b_sort=b_sort, show=True)
# Out:
# /itf-fi-ml/home/hermankn/notebooks/utils/_alluvial.py:156: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(alluvial_fan)
