# %%
import matplotlib.pyplot as plt
import seaborn as sns
import scanpy as sc
import pandas as pd
import numpy as np
import random
#import sc_toolbox

import rpy2.rinterface_lib.callbacks
import anndata2ri
import logging

from rpy2.robjects import pandas2ri
from rpy2.robjects import r

sc.settings.verbosity = 0
rpy2.rinterface_lib.callbacks.logger.setLevel(logging.ERROR)

pandas2ri.activate()
anndata2ri.activate()

# %load_ext rpy2.ipython

# %%
import anndata2ri
import rpy2.rinterface_lib.callbacks
import logging

# %%
import anndata

# %%
# %%R
# library(edgeR)
# #library(MAST)

# %%
import os

# %%
adata = sc.read('melanoma.h5ad')

# %%
adata.obs['label'] = adata.obs['level2_cell_type']

# %%
adata.obs['replicate'] = adata.obs['dataset']
#adata.obs['replicate'] = [f'{x}_{y}' for x,y in zip(adata.obs['dataset'],adata.obs['source'])]

# %%
np.max(adata.X)
# Out:
# 15937.0

# %%
#adata.layers["counts"] = adata.X.copy()

# %%
adata.obs["replicate"] = adata.obs["replicate"].astype("category")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 28834 × 21812
#     obs: 'sample', 'patient', 'batch', 'tissue', 'dataset', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', '_scvi_batch', '_scvi_labels', 'leiden', 'T cells', 'B cells', 'NK', 'macrophages', 'melanoma cells', 'endothelial cells', 'fibroblast cells', 'label', 'pred_label', 'level2_cell_type', 'level1_cell_type', 'replicate'
#     var: 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', 'dataset_colors', 'label_colors', 'leiden', 'leiden_colors', 'level1_cell_type_colors', 'neighbors', 'pred_label_colors', 'umap', 'level2_cell_type_colors'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs["sample"] = [
    f"{rep}_{l}" for rep, l in zip(adata.obs["replicate"], adata.obs["label"])
]

# %%
adata.obs["replicate"] = adata.obs["replicate"].astype("category")
adata.obs["label"] = adata.obs["label"].astype("category")
adata.obs["sample"] = adata.obs["sample"].astype("category")
#adata.obs["cell_type"] = adata.obs["cell_type"].astype("category")

# %%
adata.obsm['X_pca'] = adata.obsm['X_scVI'].copy()

# %%
anndata2ri.activate()

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
#%%R
#devtools::install_github("MarioniLab/miloR")

# %%
# %%R
# library(CellChat)
# #library(Seurat)
# Out:
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.

# %%
del adata.obsp
del adata.uns
adata.obsm.pop('X_scANVI')
adata.obsm.pop('X_scVI')
# Out:
# array([[ 0.02244956,  1.455989  ,  0.5877214 , ...,  0.3828822 ,
#          0.00564259,  0.73751056],
#        [ 0.07779748,  0.20988679,  0.06384938, ..., -1.1663426 ,
#         -0.0091617 , -0.3883643 ],
#        [ 0.02732431,  0.5757801 ,  0.39183518, ..., -0.5231973 ,
#          0.00568614, -0.13947275],
#        ...,
#        [ 0.05401376,  0.6429163 ,  0.54432565, ..., -0.5971595 ,
#          0.03806307, -1.4932345 ],
#        [ 0.01415037, -0.44304597,  1.0589092 , ...,  0.04207508,
#          0.03297498,  0.62326014],
#        [-0.02505534, -1.1696486 , -0.8130736 , ..., -0.7979734 ,
#         -0.00289451,  0.43359292]], dtype=float32)

# %%
adata_nk = sc.read('all_nk_cells.h5ad')

# %%
adata.obs['label'] = ['NK cells' if x in ['CD56bright NK cells', 'CD56dim NK cells'] else x for x in adata.obs['label']]

# %%
adata_nk.obs.index = [f'{x}_{y}' for x,y in zip(adata_nk.obs.index, adata_nk.obs['sample'])]

# %%
adata.obs['label'] = [x if x != 'NK cells' else x if not y in adata_nk[adata_nk.obs['tumor_type'] == 'melanoma'].obs.index else adata_nk[adata_nk.obs['tumor_type'] == 'melanoma'][y].obs['nhood_group'][0] for x,y in zip(adata.obs['label'], adata.obs.index)]

# %%
sc.pp.normalize_total(adata, target_sum=1e4)

# %%
sc.pp.log1p(adata)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 28812 × 21812
#     obs: 'sample', 'patient', 'batch', 'tissue', 'dataset', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', '_scvi_batch', '_scvi_labels', 'leiden', 'T cells', 'B cells', 'NK', 'macrophages', 'melanoma cells', 'endothelial cells', 'fibroblast cells', 'label', 'pred_label', 'level2_cell_type', 'level1_cell_type', 'replicate'
#     var: 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'label_colors', 'level2_cell_type_colors', 'log1p'
#     obsm: 'X_umap', 'X_pca'

# %%
# %%R -i adata
# adata
# Out:
# /home/ubuntu/miniconda3/envs/scenic/lib/python3.9/site-packages/anndata2ri/py2r.py:37: NotConvertedWarning: Conversion 'py2rpy' not defined for objects of type '<class 'NoneType'>'
#   warn(str(e), NotConvertedWarning)
# class: SingleCellExperiment
# dim: 21812 28812
# metadata(3): label_colors level2_cell_type_colors log1p
# assays(1): X
# rownames(21812): FAM138A OR4F5 ... AC240274.1 AC213203.1
# rowData names(6): mt ribo ... pct_dropout_by_counts total_counts
# colnames(28812): AAACCCAAGAGGATGA-1_GSM6622300_CM2_zhang_GSM6622300_CM2
#   AAACCCAAGGCCCACT-1_GSM6622300_CM2_zhang_GSM6622300_CM2 ...
#   TGACTTTTCATGCTCC-1_GSM5293918_smalley_GSM5293918
#   TGGCTGGAGGACCACA-1_GSM5293918_smalley_GSM5293918
# colData names(26): sample patient ... level1_cell_type replicate
# reducedDimNames(2): UMAP PCA
# mainExpName: NULL
# altExpNames(0):

# %%
# %%R
# assayNames(adata) <- c('logcounts')

# %%
# %%R
# assayNames(adata)
# Out:
# [1] "logcounts"

# %%
# %%R
# cellchat <- createCellChat(adata, group.by='label')
# Out:
# [1] "Create a CellChat object from a SingleCellExperiment object"
# The `logcounts` assay is used
# The `colData` assay in the SingleCellExperiment object is used as cell meta information
# Set cell identities for the new CellChat object
# The cell groups used for CellChat analysis are  1 2 3 4 5 6 B cells Dendritic cells Endothelial cells Fibroblasts ILCs MAIT cells Macrophages Melanoma cells Memory B cells Monocytes Regulatory T cells Tcm/Naive helper T cells Tem/Effector helper T cells Tem/Trm cytotoxic T cells Type 1 helper T cells

# %%
# %%R
# saveRDS(cellchat, file = "/tumor-data/cellchat_melanoma_groups.rds")

# %%
# %%R
# cellchat <- readRDS(file = "/tumor-data/cellchat_melanoma_groups.rds")

# %%
# %%R
# cellchat
# Out:
# An object of class CellChat created from a single dataset
#  21812 genes.
#  28812 cells.
# CellChat analysis of single cell RNA-seq data!

# %%
# %%R
# CellChatDB <- CellChatDB.human

# %%
# %%R
# showDatabaseCategory(CellChatDB)

# %%
# %%R
# CellChatDB.use <- CellChatDB

# %%
# %%R
# cellchat@DB <- CellChatDB.use

# %%
# %%R
# cellchat <- subsetData(cellchat)
# cellchat <- identifyOverExpressedGenes(cellchat)
# cellchat <- identifyOverExpressedInteractions(cellchat)
# #cellchat <- projectData(cellchat, PPI.human)
# Out:
#   |                                                  | 0 % ~calculating   |+                                                 | 1 % ~09s           |++                                                | 2 % ~09s           |++                                                | 3 % ~09s           |+++                                               | 4 % ~09s           |+++                                               | 5 % ~09s           |++++                                              | 6 % ~08s           |++++                                              | 7 % ~08s           |+++++                                             | 8 % ~08s           |+++++                                             | 9 % ~08s           |++++++                                            | 10% ~08s           |++++++                                            | 11% ~08s           |+++++++                                           | 12% ~08s           |+++++++                                           | 14% ~08s           |++++++++                                          | 15% ~08s           |++++++++                                          | 16% ~07s           |+++++++++                                         | 17% ~07s           |+++++++++                                         | 18% ~07s           |++++++++++                                        | 19% ~07s           |++++++++++                                        | 20% ~07s           |+++++++++++                                       | 21% ~07s           |+++++++++++                                       | 22% ~07s           |++++++++++++                                      | 23% ~07s           |++++++++++++                                      | 24% ~07s           |+++++++++++++                                     | 25% ~07s           |++++++++++++++                                    | 26% ~06s           |++++++++++++++                                    | 27% ~06s           |+++++++++++++++                                   | 28% ~06s           |+++++++++++++++                                   | 29% ~06s           |++++++++++++++++                                  | 30% ~06s           |++++++++++++++++                                  | 31% ~06s           |+++++++++++++++++                                 | 32% ~06s           |+++++++++++++++++                                 | 33% ~06s           |++++++++++++++++++                                | 34% ~06s           |++++++++++++++++++                                | 35% ~06s           |+++++++++++++++++++                               | 36% ~06s           |+++++++++++++++++++                               | 38% ~06s           |++++++++++++++++++++                              | 39% ~06s           |++++++++++++++++++++                              | 40% ~06s           |+++++++++++++++++++++                             | 41% ~05s           |+++++++++++++++++++++                             | 42% ~05s           |++++++++++++++++++++++                            | 43% ~05s           |++++++++++++++++++++++                            | 44% ~05s           |+++++++++++++++++++++++                           | 45% ~05s           |+++++++++++++++++++++++                           | 46% ~05s           |++++++++++++++++++++++++                          | 47% ~05s           |++++++++++++++++++++++++                          | 48% ~05s           |+++++++++++++++++++++++++                         | 49% ~05s           |+++++++++++++++++++++++++                         | 50% ~05s           |++++++++++++++++++++++++++                        | 51% ~05s           |+++++++++++++++++++++++++++                       | 52% ~04s           |+++++++++++++++++++++++++++                       | 53% ~04s           |++++++++++++++++++++++++++++                      | 54% ~04s           |++++++++++++++++++++++++++++                      | 55% ~04s           |+++++++++++++++++++++++++++++                     | 56% ~04s           |+++++++++++++++++++++++++++++         ...
#   |                                                  | 0 % ~calculating   |+                                                 | 1 % ~08s           |++                                                | 2 % ~08s           |++                                                | 3 % ~08s           |+++                                               | 4 % ~08s           |+++                                               | 5 % ~08s           |++++                                              | 7 % ~08s           |++++                                              | 8 % ~08s           |+++++                                             | 9 % ~08s           |+++++                                             | 10% ~07s           |++++++                                            | 11% ~07s           |++++++                                            | 12% ~07s           |+++++++                                           | 13% ~07s           |++++++++                                          | 14% ~07s           |++++++++                                          | 15% ~07s           |+++++++++                                         | 16% ~07s           |+++++++++                                         | 17% ~07s           |++++++++++                                        | 18% ~07s           |++++++++++                                        | 20% ~07s           |+++++++++++                                       | 21% ~06s           |+++++++++++                                       | 22% ~06s           |++++++++++++                                      | 23% ~06s           |++++++++++++                                      | 24% ~06s           |+++++++++++++                                     | 25% ~06s           |++++++++++++++                                    | 26% ~06s           |++++++++++++++                                    | 27% ~06s           |+++++++++++++++                                   | 28% ~06s           |+++++++++++++++                                   | 29% ~06s           |++++++++++++++++                                  | 30% ~06s           |++++++++++++++++                                  | 32% ~06s           |+++++++++++++++++                                 | 33% ~06s           |+++++++++++++++++                                 | 34% ~06s           |++++++++++++++++++                                | 35% ~06s           |++++++++++++++++++                                | 36% ~06s           |+++++++++++++++++++                               | 37% ~05s           |++++++++++++++++++++                              | 38% ~05s           |++++++++++++++++++++                              | 39% ~05s           |+++++++++++++++++++++                             | 40% ~05s           |+++++++++++++++++++++                             | 41% ~05s           |++++++++++++++++++++++                            | 42% ~05s           |++++++++++++++++++++++                            | 43% ~05s           |+++++++++++++++++++++++                           | 45% ~05s           |+++++++++++++++++++++++                           | 46% ~05s           |++++++++++++++++++++++++                          | 47% ~05s           |++++++++++++++++++++++++                          | 48% ~05s           |+++++++++++++++++++++++++                         | 49% ~04s           |+++++++++++++++++++++++++                         | 50% ~04s           |++++++++++++++++++++++++++                        | 51% ~04s           |+++++++++++++++++++++++++++                       | 52% ~04s           |+++++++++++++++++++++++++++                       | 53% ~04s           |++++++++++++++++++++++++++++                      | 54% ~04s           |++++++++++++++++++++++++++++                      | 55% ~04s           |+++++++++++++++++++++++++++++                     | 57% ~04s           |+++++++++++++++++++++++++++++                     | 58% ~04s           |++++++++++++++++++++++++++++++                    | 59% ~04s           |++++++++++++++++++++++++++++++        ...
#   |                                                  | 0 % ~calculating   |+                                                 | 1 % ~07s           |++                                                | 2 % ~07s           |++                                                | 4 % ~07s           |+++                                               | 5 % ~07s           |++++                                              | 6 % ~07s           |++++                                              | 8 % ~07s           |+++++                                             | 9 % ~07s           |+++++                                             | 10% ~07s           |++++++                                            | 11% ~07s           |+++++++                                           | 12% ~07s           |+++++++                                           | 14% ~06s           |++++++++                                          | 15% ~06s           |+++++++++                                         | 16% ~06s           |+++++++++                                         | 18% ~06s           |++++++++++                                        | 19% ~06s           |++++++++++                                        | 20% ~06s           |+++++++++++                                       | 21% ~06s           |++++++++++++                                      | 22% ~06s           |++++++++++++                                      | 24% ~05s           |+++++++++++++                                     | 25% ~05s           |++++++++++++++                                    | 26% ~05s           |++++++++++++++                                    | 28% ~05s           |+++++++++++++++                                   | 29% ~05s           |+++++++++++++++                                   | 30% ~05s           |++++++++++++++++                                  | 31% ~05s           |+++++++++++++++++                                 | 32% ~05s           |+++++++++++++++++                                 | 34% ~05s           |++++++++++++++++++                                | 35% ~05s           |+++++++++++++++++++                               | 36% ~05s           |+++++++++++++++++++                               | 38% ~05s           |++++++++++++++++++++                              | 39% ~05s           |++++++++++++++++++++                              | 40% ~04s           |+++++++++++++++++++++                             | 41% ~04s           |++++++++++++++++++++++                            | 42% ~04s           |++++++++++++++++++++++                            | 44% ~04s           |+++++++++++++++++++++++                           | 45% ~04s           |++++++++++++++++++++++++                          | 46% ~04s           |++++++++++++++++++++++++                          | 48% ~04s           |+++++++++++++++++++++++++                         | 49% ~04s           |+++++++++++++++++++++++++                         | 50% ~04s           |++++++++++++++++++++++++++                        | 51% ~04s           |+++++++++++++++++++++++++++                       | 52% ~04s           |+++++++++++++++++++++++++++                       | 54% ~03s           |++++++++++++++++++++++++++++                      | 55% ~03s           |+++++++++++++++++++++++++++++                     | 56% ~03s           |+++++++++++++++++++++++++++++                     | 58% ~03s           |++++++++++++++++++++++++++++++                    | 59% ~03s           |++++++++++++++++++++++++++++++                    | 60% ~03s           |+++++++++++++++++++++++++++++++                   | 61% ~03s           |++++++++++++++++++++++++++++++++                  | 62% ~03s           |++++++++++++++++++++++++++++++++                  | 64% ~03s           |+++++++++++++++++++++++++++++++++                 | 65% ~03s           |++++++++++++++++++++++++++++++++++                | 66% ~03s           |++++++++++++++++++++++++++++++++++                | 68% ~02s           |+++++++++++++++++++++++++++++++++++   ...
#   |                                                  | 0 % ~calculating   |+                                                 | 1 % ~07s           |++                                                | 2 % ~07s           |++                                                | 4 % ~07s           |+++                                               | 5 % ~07s           |++++                                              | 6 % ~07s           |++++                                              | 8 % ~06s           |+++++                                             | 9 % ~06s           |+++++                                             | 10% ~06s           |++++++                                            | 11% ~06s           |+++++++                                           | 12% ~06s           |+++++++                                           | 14% ~06s           |++++++++                                          | 15% ~06s           |+++++++++                                         | 16% ~06s           |+++++++++                                         | 18% ~06s           |++++++++++                                        | 19% ~06s           |++++++++++                                        | 20% ~06s           |+++++++++++                                       | 21% ~05s           |++++++++++++                                      | 22% ~05s           |++++++++++++                                      | 24% ~05s           |+++++++++++++                                     | 25% ~05s           |++++++++++++++                                    | 26% ~05s           |++++++++++++++                                    | 28% ~05s           |+++++++++++++++                                   | 29% ~05s           |+++++++++++++++                                   | 30% ~05s           |++++++++++++++++                                  | 31% ~05s           |+++++++++++++++++                                 | 32% ~05s           |+++++++++++++++++                                 | 34% ~05s           |++++++++++++++++++                                | 35% ~04s           |+++++++++++++++++++                               | 36% ~04s           |+++++++++++++++++++                               | 38% ~04s           |++++++++++++++++++++                              | 39% ~04s           |++++++++++++++++++++                              | 40% ~04s           |+++++++++++++++++++++                             | 41% ~04s           |++++++++++++++++++++++                            | 42% ~04s           |++++++++++++++++++++++                            | 44% ~04s           |+++++++++++++++++++++++                           | 45% ~04s           |++++++++++++++++++++++++                          | 46% ~04s           |++++++++++++++++++++++++                          | 48% ~04s           |+++++++++++++++++++++++++                         | 49% ~04s           |+++++++++++++++++++++++++                         | 50% ~04s           |++++++++++++++++++++++++++                        | 51% ~04s           |+++++++++++++++++++++++++++                       | 52% ~03s           |+++++++++++++++++++++++++++                       | 54% ~03s           |++++++++++++++++++++++++++++                      | 55% ~03s           |+++++++++++++++++++++++++++++                     | 56% ~03s           |+++++++++++++++++++++++++++++                     | 58% ~03s           |++++++++++++++++++++++++++++++                    | 59% ~03s           |++++++++++++++++++++++++++++++                    | 60% ~03s           |+++++++++++++++++++++++++++++++                   | 61% ~03s           |++++++++++++++++++++++++++++++++                  | 62% ~03s           |++++++++++++++++++++++++++++++++                  | 64% ~03s           |+++++++++++++++++++++++++++++++++                 | 65% ~03s           |++++++++++++++++++++++++++++++++++                | 66% ~02s           |++++++++++++++++++++++++++++++++++                | 68% ~02s           |+++++++++++++++++++++++++++++++++++   ...
#   |                                                  | 0 % ~calculating   |+                                                 | 1 % ~07s           |++                                                | 2 % ~07s           |++                                                | 4 % ~06s           |+++                                               | 5 % ~06s           |++++                                              | 6 % ~07s           |++++                                              | 8 % ~06s           |+++++                                             | 9 % ~06s           |+++++                                             | 10% ~06s           |++++++                                            | 11% ~06s           |+++++++                                           | 12% ~06s           |+++++++                                           | 14% ~06s           |++++++++                                          | 15% ~06s           |+++++++++                                         | 16% ~06s           |+++++++++                                         | 18% ~06s           |++++++++++                                        | 19% ~06s           |++++++++++                                        | 20% ~06s           |+++++++++++                                       | 21% ~05s           |++++++++++++                                      | 22% ~05s           |++++++++++++                                      | 24% ~05s           |+++++++++++++                                     | 25% ~05s           |++++++++++++++                                    | 26% ~05s           |++++++++++++++                                    | 28% ~05s           |+++++++++++++++                                   | 29% ~05s           |+++++++++++++++                                   | 30% ~05s           |++++++++++++++++                                  | 31% ~05s           |+++++++++++++++++                                 | 32% ~05s           |+++++++++++++++++                                 | 34% ~05s           |++++++++++++++++++                                | 35% ~05s           |+++++++++++++++++++                               | 36% ~05s           |+++++++++++++++++++                               | 38% ~05s           |++++++++++++++++++++                              | 39% ~04s           |++++++++++++++++++++                              | 40% ~04s           |+++++++++++++++++++++                             | 41% ~04s           |++++++++++++++++++++++                            | 42% ~04s           |++++++++++++++++++++++                            | 44% ~04s           |+++++++++++++++++++++++                           | 45% ~04s           |++++++++++++++++++++++++                          | 46% ~04s           |++++++++++++++++++++++++                          | 48% ~04s           |+++++++++++++++++++++++++                         | 49% ~04s           |+++++++++++++++++++++++++                         | 50% ~04s           |++++++++++++++++++++++++++                        | 51% ~04s           |+++++++++++++++++++++++++++                       | 52% ~04s           |+++++++++++++++++++++++++++                       | 54% ~03s           |++++++++++++++++++++++++++++                      | 55% ~03s           |+++++++++++++++++++++++++++++                     | 56% ~03s           |+++++++++++++++++++++++++++++                     | 58% ~03s           |++++++++++++++++++++++++++++++                    | 59% ~03s           |++++++++++++++++++++++++++++++                    | 60% ~03s           |+++++++++++++++++++++++++++++++                   | 61% ~03s           |++++++++++++++++++++++++++++++++                  | 62% ~03s           |++++++++++++++++++++++++++++++++                  | 64% ~03s           |+++++++++++++++++++++++++++++++++                 | 65% ~03s           |++++++++++++++++++++++++++++++++++                | 66% ~02s           |++++++++++++++++++++++++++++++++++                | 68% ~02s           |+++++++++++++++++++++++++++++++++++   ...
#   |                                                  | 0 % ~calculating   |+                                                 | 1 % ~06s           |++                                                | 3 % ~06s           |+++                                               | 4 % ~06s           |+++                                               | 6 % ~06s           |++++                                              | 7 % ~06s           |+++++                                             | 8 % ~06s           |+++++                                             | 10% ~06s           |++++++                                            | 11% ~06s           |+++++++                                           | 13% ~06s           |++++++++                                          | 14% ~06s           |++++++++                                          | 15% ~06s           |+++++++++                                         | 17% ~05s           |++++++++++                                        | 18% ~05s           |++++++++++                                        | 20% ~05s           |+++++++++++                                       | 21% ~05s           |++++++++++++                                      | 23% ~05s           |++++++++++++                                      | 24% ~05s           |+++++++++++++                                     | 25% ~05s           |++++++++++++++                                    | 27% ~05s           |+++++++++++++++                                   | 28% ~05s           |+++++++++++++++                                   | 30% ~04s           |++++++++++++++++                                  | 31% ~04s           |+++++++++++++++++                                 | 32% ~04s           |+++++++++++++++++                                 | 34% ~04s           |++++++++++++++++++                                | 35% ~04s           |+++++++++++++++++++                               | 37% ~04s           |++++++++++++++++++++                              | 38% ~04s           |++++++++++++++++++++                              | 39% ~04s           |+++++++++++++++++++++                             | 41% ~04s           |++++++++++++++++++++++                            | 42% ~04s           |++++++++++++++++++++++                            | 44% ~04s           |+++++++++++++++++++++++                           | 45% ~04s           |++++++++++++++++++++++++                          | 46% ~04s           |++++++++++++++++++++++++                          | 48% ~03s           |+++++++++++++++++++++++++                         | 49% ~03s           |++++++++++++++++++++++++++                        | 51% ~03s           |+++++++++++++++++++++++++++                       | 52% ~03s           |+++++++++++++++++++++++++++                       | 54% ~03s           |++++++++++++++++++++++++++++                      | 55% ~03s           |+++++++++++++++++++++++++++++                     | 56% ~03s           |+++++++++++++++++++++++++++++                     | 58% ~03s           |++++++++++++++++++++++++++++++                    | 59% ~03s           |+++++++++++++++++++++++++++++++                   | 61% ~03s           |+++++++++++++++++++++++++++++++                   | 62% ~03s           |++++++++++++++++++++++++++++++++                  | 63% ~02s           |+++++++++++++++++++++++++++++++++                 | 65% ~02s           |++++++++++++++++++++++++++++++++++                | 66% ~02s           |++++++++++++++++++++++++++++++++++                | 68% ~02s           |+++++++++++++++++++++++++++++++++++               | 69% ~02s           |++++++++++++++++++++++++++++++++++++              | 70% ~02s           |++++++++++++++++++++++++++++++++++++              | 72% ~02s           |+++++++++++++++++++++++++++++++++++++             | 73% ~02s           |++++++++++++++++++++++++++++++++++++++            | 75% ~02s           |+++++++++++++++++++++++++++++++++++++++           | 76% ~02s           |+++++++++++++++++++++++++++++++++++++ ...
#   |                                                  | 0 % ~calculating   |+                                                 | 2 % ~07s           |++                                                | 3 % ~06s           |+++                                               | 5 % ~06s           |++++                                              | 6 % ~06s           |++++                                              | 8 % ~05s           |+++++                                             | 9 % ~05s           |++++++                                            | 11% ~05s           |+++++++                                           | 12% ~05s           |+++++++                                           | 14% ~05s           |++++++++                                          | 15% ~05s           |+++++++++                                         | 17% ~05s           |++++++++++                                        | 18% ~05s           |++++++++++                                        | 20% ~05s           |+++++++++++                                       | 22% ~05s           |++++++++++++                                      | 23% ~04s           |+++++++++++++                                     | 25% ~04s           |++++++++++++++                                    | 26% ~04s           |++++++++++++++                                    | 28% ~04s           |+++++++++++++++                                   | 29% ~04s           |++++++++++++++++                                  | 31% ~04s           |+++++++++++++++++                                 | 32% ~04s           |+++++++++++++++++                                 | 34% ~04s           |++++++++++++++++++                                | 35% ~04s           |+++++++++++++++++++                               | 37% ~04s           |++++++++++++++++++++                              | 38% ~04s           |++++++++++++++++++++                              | 40% ~04s           |+++++++++++++++++++++                             | 42% ~04s           |++++++++++++++++++++++                            | 43% ~03s           |+++++++++++++++++++++++                           | 45% ~03s           |++++++++++++++++++++++++                          | 46% ~03s           |++++++++++++++++++++++++                          | 48% ~03s           |+++++++++++++++++++++++++                         | 49% ~03s           |++++++++++++++++++++++++++                        | 51% ~03s           |+++++++++++++++++++++++++++                       | 52% ~03s           |+++++++++++++++++++++++++++                       | 54% ~03s           |++++++++++++++++++++++++++++                      | 55% ~03s           |+++++++++++++++++++++++++++++                     | 57% ~03s           |++++++++++++++++++++++++++++++                    | 58% ~02s           |++++++++++++++++++++++++++++++                    | 60% ~02s           |+++++++++++++++++++++++++++++++                   | 62% ~02s           |++++++++++++++++++++++++++++++++                  | 63% ~02s           |+++++++++++++++++++++++++++++++++                 | 65% ~02s           |++++++++++++++++++++++++++++++++++                | 66% ~02s           |++++++++++++++++++++++++++++++++++                | 68% ~02s           |+++++++++++++++++++++++++++++++++++               | 69% ~02s           |++++++++++++++++++++++++++++++++++++              | 71% ~02s           |+++++++++++++++++++++++++++++++++++++             | 72% ~02s           |+++++++++++++++++++++++++++++++++++++             | 74% ~02s           |++++++++++++++++++++++++++++++++++++++            | 75% ~01s           |+++++++++++++++++++++++++++++++++++++++           | 77% ~01s           |++++++++++++++++++++++++++++++++++++++++          | 78% ~01s           |++++++++++++++++++++++++++++++++++++++++          | 80% ~01s           |+++++++++++++++++++++++++++++++++++++++++         | 82% ~01s           |++++++++++++++++++++++++++++++++++++++++++        | 83% ~01s           |+++++++++++++++++++++++++++++++++++++ ...
#   |                                                  | 0 % ~calculating   |+                                                 | 1 % ~10s           |++                                                | 2 % ~11s           |++                                                | 4 % ~10s           |+++                                               | 5 % ~10s           |++++                                              | 6 % ~10s           |++++                                              | 8 % ~10s           |+++++                                             | 9 % ~10s           |+++++                                             | 10% ~10s           |++++++                                            | 11% ~10s           |+++++++                                           | 12% ~09s           |+++++++                                           | 14% ~09s           |++++++++                                          | 15% ~09s           |+++++++++                                         | 16% ~09s           |+++++++++                                         | 18% ~09s           |++++++++++                                        | 19% ~09s           |++++++++++                                        | 20% ~08s           |+++++++++++                                       | 21% ~08s           |++++++++++++                                      | 22% ~08s           |++++++++++++                                      | 24% ~08s           |+++++++++++++                                     | 25% ~08s           |++++++++++++++                                    | 26% ~08s           |++++++++++++++                                    | 28% ~08s           |+++++++++++++++                                   | 29% ~07s           |+++++++++++++++                                   | 30% ~07s           |++++++++++++++++                                  | 31% ~07s           |+++++++++++++++++                                 | 32% ~07s           |+++++++++++++++++                                 | 34% ~07s           |++++++++++++++++++                                | 35% ~07s           |+++++++++++++++++++                               | 36% ~07s           |+++++++++++++++++++                               | 38% ~07s           |++++++++++++++++++++                              | 39% ~07s           |++++++++++++++++++++                              | 40% ~06s           |+++++++++++++++++++++                             | 41% ~06s           |++++++++++++++++++++++                            | 42% ~06s           |++++++++++++++++++++++                            | 44% ~06s           |+++++++++++++++++++++++                           | 45% ~06s           |++++++++++++++++++++++++                          | 46% ~06s           |++++++++++++++++++++++++                          | 48% ~06s           |+++++++++++++++++++++++++                         | 49% ~06s           |+++++++++++++++++++++++++                         | 50% ~05s           |++++++++++++++++++++++++++                        | 51% ~05s           |+++++++++++++++++++++++++++                       | 52% ~05s           |+++++++++++++++++++++++++++                       | 54% ~05s           |++++++++++++++++++++++++++++                      | 55% ~05s           |+++++++++++++++++++++++++++++                     | 56% ~05s           |+++++++++++++++++++++++++++++                     | 58% ~05s           |++++++++++++++++++++++++++++++                    | 59% ~04s           |++++++++++++++++++++++++++++++                    | 60% ~04s           |+++++++++++++++++++++++++++++++                   | 61% ~04s           |++++++++++++++++++++++++++++++++                  | 62% ~04s           |++++++++++++++++++++++++++++++++                  | 64% ~04s           |+++++++++++++++++++++++++++++++++                 | 65% ~04s           |++++++++++++++++++++++++++++++++++                | 66% ~04s           |++++++++++++++++++++++++++++++++++                | 68% ~03s           |+++++++++++++++++++++++++++++++++++   ...
#   |                                                  | 0 % ~calculating   |+                                                 | 1 % ~14s           |++                                                | 2 % ~14s           |++                                                | 4 % ~14s           |+++                                               | 5 % ~13s           |++++                                              | 6 % ~13s           |++++                                              | 7 % ~13s           |+++++                                             | 9 % ~13s           |+++++                                             | 10% ~13s           |++++++                                            | 11% ~12s           |+++++++                                           | 12% ~12s           |+++++++                                           | 13% ~12s           |++++++++                                          | 15% ~12s           |++++++++                                          | 16% ~12s           |+++++++++                                         | 17% ~11s           |++++++++++                                        | 18% ~11s           |++++++++++                                        | 20% ~11s           |+++++++++++                                       | 21% ~11s           |+++++++++++                                       | 22% ~11s           |++++++++++++                                      | 23% ~11s           |+++++++++++++                                     | 24% ~10s           |+++++++++++++                                     | 26% ~10s           |++++++++++++++                                    | 27% ~10s           |+++++++++++++++                                   | 28% ~10s           |+++++++++++++++                                   | 29% ~10s           |++++++++++++++++                                  | 30% ~10s           |++++++++++++++++                                  | 32% ~09s           |+++++++++++++++++                                 | 33% ~09s           |++++++++++++++++++                                | 34% ~09s           |++++++++++++++++++                                | 35% ~09s           |+++++++++++++++++++                               | 37% ~09s           |+++++++++++++++++++                               | 38% ~09s           |++++++++++++++++++++                              | 39% ~09s           |+++++++++++++++++++++                             | 40% ~08s           |+++++++++++++++++++++                             | 41% ~08s           |++++++++++++++++++++++                            | 43% ~08s           |++++++++++++++++++++++                            | 44% ~08s           |+++++++++++++++++++++++                           | 45% ~08s           |++++++++++++++++++++++++                          | 46% ~08s           |++++++++++++++++++++++++                          | 48% ~07s           |+++++++++++++++++++++++++                         | 49% ~07s           |+++++++++++++++++++++++++                         | 50% ~07s           |++++++++++++++++++++++++++                        | 51% ~07s           |+++++++++++++++++++++++++++                       | 52% ~07s           |+++++++++++++++++++++++++++                       | 54% ~07s           |++++++++++++++++++++++++++++                      | 55% ~06s           |+++++++++++++++++++++++++++++                     | 56% ~06s           |+++++++++++++++++++++++++++++                     | 57% ~06s           |++++++++++++++++++++++++++++++                    | 59% ~06s           |++++++++++++++++++++++++++++++                    | 60% ~06s           |+++++++++++++++++++++++++++++++                   | 61% ~06s           |++++++++++++++++++++++++++++++++                  | 62% ~05s           |++++++++++++++++++++++++++++++++                  | 63% ~05s           |+++++++++++++++++++++++++++++++++                 | 65% ~05s           |+++++++++++++++++++++++++++++++++                 | 66% ~05s           |++++++++++++++++++++++++++++++++++    ...
#   |                                                  | 0 % ~calculating   |+                                                 | 1 % ~19s           |++                                                | 2 % ~18s           |++                                                | 4 % ~17s           |+++                                               | 5 % ~17s           |+++                                               | 6 % ~17s           |++++                                              | 7 % ~16s           |+++++                                             | 8 % ~16s           |+++++                                             | 9 % ~16s           |++++++                                            | 11% ~16s           |++++++                                            | 12% ~15s           |+++++++                                           | 13% ~15s           |++++++++                                          | 14% ~15s           |++++++++                                          | 15% ~15s           |+++++++++                                         | 16% ~15s           |+++++++++                                         | 18% ~15s           |++++++++++                                        | 19% ~15s           |++++++++++                                        | 20% ~15s           |+++++++++++                                       | 21% ~15s           |++++++++++++                                      | 22% ~15s           |++++++++++++                                      | 24% ~14s           |+++++++++++++                                     | 25% ~14s           |+++++++++++++                                     | 26% ~14s           |++++++++++++++                                    | 27% ~14s           |+++++++++++++++                                   | 28% ~14s           |+++++++++++++++                                   | 29% ~13s           |++++++++++++++++                                  | 31% ~13s           |++++++++++++++++                                  | 32% ~13s           |+++++++++++++++++                                 | 33% ~13s           |++++++++++++++++++                                | 34% ~12s           |++++++++++++++++++                                | 35% ~12s           |+++++++++++++++++++                               | 36% ~12s           |+++++++++++++++++++                               | 38% ~12s           |++++++++++++++++++++                              | 39% ~12s           |++++++++++++++++++++                              | 40% ~12s           |+++++++++++++++++++++                             | 41% ~11s           |++++++++++++++++++++++                            | 42% ~11s           |++++++++++++++++++++++                            | 44% ~11s           |+++++++++++++++++++++++                           | 45% ~11s           |+++++++++++++++++++++++                           | 46% ~10s           |++++++++++++++++++++++++                          | 47% ~10s           |+++++++++++++++++++++++++                         | 48% ~10s           |+++++++++++++++++++++++++                         | 49% ~10s           |++++++++++++++++++++++++++                        | 51% ~10s           |++++++++++++++++++++++++++                        | 52% ~09s           |+++++++++++++++++++++++++++                       | 53% ~09s           |++++++++++++++++++++++++++++                      | 54% ~09s           |++++++++++++++++++++++++++++                      | 55% ~09s           |+++++++++++++++++++++++++++++                     | 56% ~08s           |+++++++++++++++++++++++++++++                     | 58% ~08s           |++++++++++++++++++++++++++++++                    | 59% ~08s           |++++++++++++++++++++++++++++++                    | 60% ~08s           |+++++++++++++++++++++++++++++++                   | 61% ~08s           |++++++++++++++++++++++++++++++++                  | 62% ~07s           |++++++++++++++++++++++++++++++++                  | 64% ~07s           |+++++++++++++++++++++++++++++++++     ...
#   |                                                  | 0 % ~calculating   |+                                                 | 1 % ~08s           |++                                                | 2 % ~08s           |++                                                | 3 % ~09s           |+++                                               | 4 % ~09s           |+++                                               | 5 % ~08s           |++++                                              | 6 % ~08s           |++++                                              | 7 % ~08s           |+++++                                             | 8 % ~08s           |+++++                                             | 9 % ~08s           |++++++                                            | 10% ~08s           |++++++                                            | 11% ~08s           |+++++++                                           | 12% ~07s           |+++++++                                           | 14% ~07s           |++++++++                                          | 15% ~07s           |++++++++                                          | 16% ~07s           |+++++++++                                         | 17% ~07s           |+++++++++                                         | 18% ~07s           |++++++++++                                        | 19% ~07s           |++++++++++                                        | 20% ~07s           |+++++++++++                                       | 21% ~07s           |+++++++++++                                       | 22% ~07s           |++++++++++++                                      | 23% ~07s           |++++++++++++                                      | 24% ~07s           |+++++++++++++                                     | 25% ~06s           |++++++++++++++                                    | 26% ~06s           |++++++++++++++                                    | 27% ~06s           |+++++++++++++++                                   | 28% ~06s           |+++++++++++++++                                   | 29% ~06s           |++++++++++++++++                                  | 30% ~06s           |++++++++++++++++                                  | 31% ~06s           |+++++++++++++++++                                 | 32% ~06s           |+++++++++++++++++                                 | 33% ~06s           |++++++++++++++++++                                | 34% ~06s           |++++++++++++++++++                                | 35% ~05s           |+++++++++++++++++++                               | 36% ~05s           |+++++++++++++++++++                               | 38% ~05s           |++++++++++++++++++++                              | 39% ~05s           |++++++++++++++++++++                              | 40% ~05s           |+++++++++++++++++++++                             | 41% ~05s           |+++++++++++++++++++++                             | 42% ~05s           |++++++++++++++++++++++                            | 43% ~05s           |++++++++++++++++++++++                            | 44% ~05s           |+++++++++++++++++++++++                           | 45% ~05s           |+++++++++++++++++++++++                           | 46% ~05s           |++++++++++++++++++++++++                          | 47% ~05s           |++++++++++++++++++++++++                          | 48% ~04s           |+++++++++++++++++++++++++                         | 49% ~04s           |+++++++++++++++++++++++++                         | 50% ~04s           |++++++++++++++++++++++++++                        | 51% ~04s           |+++++++++++++++++++++++++++                       | 52% ~04s           |+++++++++++++++++++++++++++                       | 53% ~04s           |++++++++++++++++++++++++++++                      | 54% ~04s           |++++++++++++++++++++++++++++                      | 55% ~04s           |+++++++++++++++++++++++++++++                     | 56% ~04s           |+++++++++++++++++++++++++++++         ...
# ...
#   |                                                  | 0 % ~calculating   |+                                                 | 1 % ~07s           |++                                                | 3 % ~07s           |++                                                | 4 % ~07s           |+++                                               | 5 % ~06s           |++++                                              | 6 % ~06s           |++++                                              | 8 % ~06s           |+++++                                             | 9 % ~06s           |++++++                                            | 10% ~06s           |++++++                                            | 11% ~06s           |+++++++                                           | 13% ~06s           |+++++++                                           | 14% ~06s           |++++++++                                          | 15% ~06s           |+++++++++                                         | 16% ~06s           |+++++++++                                         | 18% ~06s           |++++++++++                                        | 19% ~06s           |+++++++++++                                       | 20% ~05s           |+++++++++++                                       | 22% ~05s           |++++++++++++                                      | 23% ~05s           |+++++++++++++                                     | 24% ~05s           |+++++++++++++                                     | 25% ~05s           |++++++++++++++                                    | 27% ~05s           |++++++++++++++                                    | 28% ~05s           |+++++++++++++++                                   | 29% ~05s           |++++++++++++++++                                  | 30% ~05s           |++++++++++++++++                                  | 32% ~05s           |+++++++++++++++++                                 | 33% ~05s           |++++++++++++++++++                                | 34% ~04s           |++++++++++++++++++                                | 35% ~04s           |+++++++++++++++++++                               | 37% ~04s           |+++++++++++++++++++                               | 38% ~04s           |++++++++++++++++++++                              | 39% ~04s           |+++++++++++++++++++++                             | 41% ~04s           |+++++++++++++++++++++                             | 42% ~04s           |++++++++++++++++++++++                            | 43% ~04s           |+++++++++++++++++++++++                           | 44% ~04s           |+++++++++++++++++++++++                           | 46% ~04s           |++++++++++++++++++++++++                          | 47% ~04s           |+++++++++++++++++++++++++                         | 48% ~04s           |+++++++++++++++++++++++++                         | 49% ~03s           |++++++++++++++++++++++++++                        | 51% ~03s           |++++++++++++++++++++++++++                        | 52% ~03s           |+++++++++++++++++++++++++++                       | 53% ~03s           |++++++++++++++++++++++++++++                      | 54% ~03s           |++++++++++++++++++++++++++++                      | 56% ~03s           |+++++++++++++++++++++++++++++                     | 57% ~03s           |++++++++++++++++++++++++++++++                    | 58% ~03s           |++++++++++++++++++++++++++++++                    | 59% ~03s           |+++++++++++++++++++++++++++++++                   | 61% ~03s           |++++++++++++++++++++++++++++++++                  | 62% ~03s           |++++++++++++++++++++++++++++++++                  | 63% ~03s           |+++++++++++++++++++++++++++++++++                 | 65% ~03s           |+++++++++++++++++++++++++++++++++                 | 66% ~02s           |++++++++++++++++++++++++++++++++++                | 67% ~02s           |+++++++++++++++++++++++++++++++++++               | 68% ~02s           |+++++++++++++++++++++++++++++++++++   ...
#   |                                                  | 0 % ~calculating   |+                                                 | 1 % ~00s           |++                                                | 3 % ~00s           |++                                                | 4 % ~00s           |+++                                               | 5 % ~00s           |++++                                              | 6 % ~00s           |++++                                              | 8 % ~00s           |+++++                                             | 9 % ~00s           |++++++                                            | 10% ~00s           |++++++                                            | 11% ~00s           |+++++++                                           | 13% ~00s           |+++++++                                           | 14% ~00s           |++++++++                                          | 15% ~00s           |+++++++++                                         | 16% ~00s           |+++++++++                                         | 18% ~00s           |++++++++++                                        | 19% ~00s           |+++++++++++                                       | 20% ~00s           |+++++++++++                                       | 22% ~00s           |++++++++++++                                      | 23% ~00s           |+++++++++++++                                     | 24% ~00s           |+++++++++++++                                     | 25% ~00s           |++++++++++++++                                    | 27% ~00s           |++++++++++++++                                    | 28% ~00s           |+++++++++++++++                                   | 29% ~00s           |++++++++++++++++                                  | 30% ~00s           |++++++++++++++++                                  | 32% ~00s           |+++++++++++++++++                                 | 33% ~00s           |++++++++++++++++++                                | 34% ~00s           |++++++++++++++++++                                | 35% ~00s           |+++++++++++++++++++                               | 37% ~00s           |+++++++++++++++++++                               | 38% ~00s           |++++++++++++++++++++                              | 39% ~00s           |+++++++++++++++++++++                             | 41% ~00s           |+++++++++++++++++++++                             | 42% ~00s           |++++++++++++++++++++++                            | 43% ~00s           |+++++++++++++++++++++++                           | 44% ~00s           |+++++++++++++++++++++++                           | 46% ~00s           |++++++++++++++++++++++++                          | 47% ~00s           |+++++++++++++++++++++++++                         | 48% ~00s           |+++++++++++++++++++++++++                         | 49% ~00s           |++++++++++++++++++++++++++                        | 51% ~00s           |++++++++++++++++++++++++++                        | 52% ~00s           |+++++++++++++++++++++++++++                       | 53% ~00s           |++++++++++++++++++++++++++++                      | 54% ~00s           |++++++++++++++++++++++++++++                      | 56% ~00s           |+++++++++++++++++++++++++++++                     | 57% ~00s           |++++++++++++++++++++++++++++++                    | 58% ~00s           |++++++++++++++++++++++++++++++                    | 59% ~00s           |+++++++++++++++++++++++++++++++                   | 61% ~00s           |++++++++++++++++++++++++++++++++                  | 62% ~00s           |++++++++++++++++++++++++++++++++                  | 63% ~00s           |+++++++++++++++++++++++++++++++++                 | 65% ~00s           |+++++++++++++++++++++++++++++++++                 | 66% ~00s           |++++++++++++++++++++++++++++++++++                | 67% ~00s           |+++++++++++++++++++++++++++++++++++               | 68% ~00s           |+++++++++++++++++++++++++++++++++++   ...
#   |                                                  | 0 % ~calculating   |+                                                 | 1 % ~01s           |++                                                | 2 % ~01s           |++                                                | 3 % ~01s           |+++                                               | 4 % ~01s           |+++                                               | 5 % ~01s           |++++                                              | 6 % ~01s           |++++                                              | 7 % ~01s           |+++++                                             | 8 % ~01s           |+++++                                             | 9 % ~01s           |++++++                                            | 10% ~01s           |++++++                                            | 11% ~01s           |+++++++                                           | 12% ~01s           |+++++++                                           | 13% ~01s           |++++++++                                          | 14% ~01s           |++++++++                                          | 15% ~01s           |+++++++++                                         | 16% ~01s           |+++++++++                                         | 18% ~01s           |++++++++++                                        | 19% ~01s           |++++++++++                                        | 20% ~01s           |+++++++++++                                       | 21% ~01s           |+++++++++++                                       | 22% ~01s           |++++++++++++                                      | 23% ~01s           |++++++++++++                                      | 24% ~00s           |+++++++++++++                                     | 25% ~00s           |+++++++++++++                                     | 26% ~00s           |++++++++++++++                                    | 27% ~00s           |++++++++++++++                                    | 28% ~00s           |+++++++++++++++                                   | 29% ~00s           |+++++++++++++++                                   | 30% ~00s           |++++++++++++++++                                  | 31% ~00s           |++++++++++++++++                                  | 32% ~00s           |+++++++++++++++++                                 | 33% ~00s           |++++++++++++++++++                                | 34% ~00s           |++++++++++++++++++                                | 35% ~00s           |+++++++++++++++++++                               | 36% ~00s           |+++++++++++++++++++                               | 37% ~00s           |++++++++++++++++++++                              | 38% ~00s           |++++++++++++++++++++                              | 39% ~00s           |+++++++++++++++++++++                             | 40% ~00s           |+++++++++++++++++++++                             | 41% ~00s           |++++++++++++++++++++++                            | 42% ~00s           |++++++++++++++++++++++                            | 43% ~00s           |+++++++++++++++++++++++                           | 44% ~00s           |+++++++++++++++++++++++                           | 45% ~00s           |++++++++++++++++++++++++                          | 46% ~00s           |++++++++++++++++++++++++                          | 47% ~00s           |+++++++++++++++++++++++++                         | 48% ~00s           |+++++++++++++++++++++++++                         | 49% ~00s           |++++++++++++++++++++++++++                        | 51% ~00s           |++++++++++++++++++++++++++                        | 52% ~00s           |+++++++++++++++++++++++++++                       | 53% ~00s           |+++++++++++++++++++++++++++                       | 54% ~00s           |++++++++++++++++++++++++++++                      | 55% ~00s           |++++++++++++++++++++++++++++                      | 56% ~00s           |+++++++++++++++++++++++++++++         ...

# %%
#%%R
#saveRDS(cellchat, file = "/tumor-data/cellchat.rds")

# %%
# %%R
# cellchat <- computeCommunProb(cellchat)
# Out:
# triMean is used for calculating the average gene expression per cell group.
# [1] ">>> Run CellChat on sc/snRNA-seq data <<< [2023-09-14 08:18:12]"
# [1] ">>> CellChat inference is done. Parameter values are stored in `object@options$parameter` <<< [2023-09-14 08:29:51]"

# %%
# %%R
# cellchat <- filterCommunication(cellchat, min.cells = 10)

# %%
# %%R
# cellchat <- computeCommunProbPathway(cellchat)

# %%
# %%R
# cellchat <- aggregateNet(cellchat)

# %%
# %%R
# saveRDS(cellchat, file = "/tumor-data/cellchat_melanoma_groups.rds")

# %%
# %%R
# cellchat <- readRDS(file = "/tumor-data/cellchat_melanoma_groups.rds")

# %%
'B cells CD56bright NK cells CD56dim NK cells Dendritic cells Endothelial cells Epithelial Stroma Fibroblasts ILCs Late erythroid Macrophages Mast cells Memory B cells NKT cells Plasma cells Regulatory T cells Tcm/Naive helper T cells Tem/Effector helper T cells Tem/Trm cytotoxic T cells '
# Out:
# 'B cells CD56bright NK cells CD56dim NK cells Dendritic cells Endothelial cells Epithelial Stroma Fibroblasts ILCs Late erythroid Macrophages Mast cells Memory B cells NKT cells Plasma cells Regulatory T cells Tcm/Naive helper T cells Tem/Effector helper T cells Tem/Trm cytotoxic T cells '

# %%
# %%R
# groupSize <- as.numeric(table(cellchat@idents))
# par(mfrow = c(1,1), xpd=TRUE)
# #svglite(file ="number_of_interactions_all_glio.svg")
# netVisual_circle(cellchat@net$count, vertex.weight = groupSize, weight.scale = T, label.edge= F, title.name = "Number of interactions")
# #netVisual_circle(cellchat@net$weight, targets.use=c(2,3), vertex.weight = groupSize, weight.scale = T, label.edge= F, title.name = "Interaction weights/strength")
# #ggsave('number_of_interactions_cd56bright_cd56dim_as_targets.pdf')
# #dev.off()

# %%
# %%R
# groupSize <- as.numeric(table(cellchat@idents))
# par(mfrow = c(1,1), xpd=TRUE)
# #svglite(file ="number_of_interactions_all_glio.svg")
# netVisual_circle(cellchat@net$count, vertex.weight = groupSize, weight.scale = T, label.edge= F, title.name = "Number of interactions")
# #netVisual_circle(cellchat@net$weight, targets.use=c(2,3), vertex.weight = groupSize, weight.scale = T, label.edge= F, title.name = "Interaction weights/strength")
# #ggsave('number_of_interactions_cd56bright_cd56dim_as_targets.pdf')
# #dev.off()

# %%
# %%R
# groupSize <- as.numeric(table(cellchat@idents))
# par(mfrow = c(1,1), xpd=TRUE)
# #svglite(file ="interaction_weights_all_glio.svg")
# #netVisual_circle(cellchat@net$count, vertex.weight = groupSize, weight.scale = T, label.edge= F, title.name = "Number of interactions")
# netVisual_circle(cellchat@net$weight, vertex.weight = groupSize, weight.scale = T, label.edge= F, title.name = "Interaction weights/strength")
# #ggsave('number_of_interactions_cd56bright_cd56dim_as_targets.pdf')
# #dev.off()

# %%
# %%R
# groupSize <- as.numeric(table(cellchat@idents))
# par(mfrow = c(1,1), xpd=TRUE)
# #svglite(file ="number_of_interactions_cd56bright_cd56dim_as_targets_glio.svg")
# netVisual_circle(cellchat@net$count, targets.use=c(2,3), vertex.weight = groupSize, weight.scale = T, label.edge= F, title.name = "Number of interactions")
# #netVisual_circle(cellchat@net$weight, targets.use=c(2,3), vertex.weight = groupSize, weight.scale = T, label.edge= F, title.name = "Interaction weights/strength")
# #ggsave('number_of_interactions_cd56bright_cd56dim_as_targets.pdf')
# #dev.off()

# %%
# %%R
# groupSize <- as.numeric(table(cellchat@idents))
# par(mfrow = c(1,1), xpd=TRUE)
# #netVisual_circle(cellchat@net$count, targets.use=c(2,3), vertex.weight = groupSize, weight.scale = T, label.edge= F, title.name = "Number of interactions")
# #svglite(file ="interaction_weights_cd56bright_cd56dim_as_targets_glio.svg")
# netVisual_circle(cellchat@net$weight, targets.use=c(2,3), vertex.weight = groupSize, weight.scale = T, label.edge= F, title.name = "Interaction weights/strength")
# #dev.off()
# #ggsave('interaction_weights_cd56bright_cd56dim_as_targets.pdf')

# %%
# %%R
# groupSize <- as.numeric(table(cellchat@idents))
# par(mfrow = c(1,1), xpd=TRUE)
# #svglite(file ="number_of_interactions_cd56bright_cd56dim_as_sources_glio.svg")
# netVisual_circle(cellchat@net$count, sources.use=c(2,3), vertex.weight = groupSize, weight.scale = T, label.edge= F, title.name = "Number of interactions")
# #netVisual_circle(cellchat@net$weight, sources.use=c(2,3), vertex.weight = groupSize, weight.scale = T, label.edge= F, title.name = "Interaction weights/strength")
# #dev.off()
# #ggsave('number_of_interactions_cd56bright_cd56dim_as_sources.pdf')

# %%
# %%R
# groupSize <- as.numeric(table(cellchat@idents))
# par(mfrow = c(1,1), xpd=TRUE)
# #netVisual_circle(cellchat@net$count, targets.use=c(2,3), vertex.weight = groupSize, weight.scale = T, label.edge= F, title.name = "Number of interactions")
# #svglite(file ="interaction_weights_cd56bright_cd56dim_as_sources_glio.svg")
# netVisual_circle(cellchat@net$weight, sources.use=c(2,3), vertex.weight = groupSize, weight.scale = T, label.edge= F, title.name = "Interaction weights/strength")
# #dev.off()
# #ggsave('interaction_weights_cd56bright_cd56dim_as_sources.pdf')

# %%
# %%R
# mat <- cellchat@net$weight
# par(mfrow = c(3,3), xpd=TRUE)
# for (i in 1:nrow(mat)) {
#   mat2 <- matrix(0, nrow = nrow(mat), ncol = ncol(mat), dimnames = dimnames(mat))
#   mat2[i, ] <- mat[i, ]
#   netVisual_circle(mat2, vertex.weight = groupSize, weight.scale = T, edge.weight.max = max(mat), title.name = rownames(mat)[i])
# }

# %% [markdown]
# ### CXCL

# %%
# %%R
# pathways.show <- c("CXCL")
# # Hierarchy plot
# # Here we define `vertex.receive` so that the left portion of the hierarchy plot shows signaling to fibroblast and the right portion shows signaling to immune cells
# vertex.receiver = seq(1,4) # a numeric vector.
# netVisual_aggregate(cellchat, signaling = pathways.show,  vertex.receiver = vertex.receiver)
# # Circle plot
# #par(mfrow=c(1,1))
# #svglite(file ="CXCL_pathway_netvisual_aggregate_circle_glio.svg")
# netVisual_aggregate(cellchat, signaling = pathways.show, layout = "circle")
# #dev.off()
# #ggsave('CXCL_pathway_netvisual_aggregate_circle.pdf')

# %%
# %%R
# # Chord diagram
# par(mfrow=c(1,1))
# #svglite(file ="CXCL_pathway_netvisual_aggregate_chord_glio.svg")
# netVisual_aggregate(cellchat, signaling = pathways.show, layout = "chord")
# #dev.off()

# %%
# %%R
# # Heatmap
# par(mfrow=c(1,1))
# netVisual_heatmap(cellchat, signaling = pathways.show, color.heatmap = "Reds")
# #> Do heatmap based on a single object
# #ggsave('CXCL_pathway_netvisual_heatmap_glio.pdf')

# %%
# %%R
# netAnalysis_contribution(cellchat, signaling = pathways.show)
# #ggsave('CXCL_pathway_contribution_glio.pdf')

# %%
# %%R
# pairLR.CXCL <- extractEnrichedLR(cellchat, signaling = pathways.show, geneLR.return = FALSE)
# LR.show <- pairLR.CXCL[4,] # show one ligand-receptor pair
# # Hierarchy plot
# vertex.receiver = seq(1,4) # a numeric vector
# netVisual_individual(cellchat, signaling = pathways.show,  pairLR.use = LR.show, vertex.receiver = vertex.receiver)
# #> [[1]]
# # Circle plot
# svglite(file ="CXCL12_CXCR4_glio.svg")
# netVisual_individual(cellchat, signaling = pathways.show, pairLR.use = LR.show, layout = "circle")
# #ggsave('CXCL12_CXCR4.pdf')
# dev.off()

# %%
# %%R
# svglite(file ="CXCL12_CXCR4_chord_glio.svg")
# netVisual_individual(cellchat, signaling = pathways.show, pairLR.use = LR.show, layout = "chord")
# dev.off()

# %%
# %%R
# netVisual_bubble(cellchat, targets.use = c(2,3), signaling = c("CXCL"), remove.isolate = FALSE)
# ggsave('cxcl12_cxcr4_nk_cells_bubble.pdf')

# %%
# %%R
# plotGeneExpression(cellchat, signaling = "CXCL")
# ggsave('CXCL_gene_expression.pdf')

# %%
# %%R
# # Compute the network centrality scores
# cellchat <- netAnalysis_computeCentrality(cellchat, slot.name = "netP") # the slot 'netP' means the inferred intercellular communication network of signaling pathways
# # Visualize the computed centrality scores using heatmap, allowing ready identification of major signaling roles of cell groups
# svglite(file ="CXCL_sig_pathway_role_network.svg")
# netAnalysis_signalingRole_network(cellchat, signaling = pathways.show, width = 8, height = 2.5, font.size = 10)
# #ggsave('CXCL_sig_pathway_role_network.pdf')
# dev.off()

# %% [markdown]
# ### CCL

# %%
# %%R
# pathways.show <- c("CCL")
# # Hierarchy plot
# # Here we define `vertex.receive` so that the left portion of the hierarchy plot shows signaling to fibroblast and the right portion shows signaling to immune cells
# vertex.receiver = seq(1,4) # a numeric vector.
# netVisual_aggregate(cellchat, signaling = pathways.show,  vertex.receiver = vertex.receiver)
# # Circle plot
# par(mfrow=c(1,1))
# #svglite(file ="CCL_pathway_netvisual_aggregate_circle.svg")
# netVisual_aggregate(cellchat, signaling = pathways.show, layout = "circle")
# #dev.off()
# #ggsave('CCL_pathway_netvisual_aggregate_circle.pdf')

# %%
# %%R
# # Chord diagram
# par(mfrow=c(1,1))
# #svglite(file ="CCL_pathway_netvisual_aggregate_chord.svg")
# netVisual_aggregate(cellchat, signaling = pathways.show, layout = "chord")
# #dev.off()
# #ggsave('CCL_pathway_netvisual_aggregate_chord.pdf')

# %%
# %%R
# # Heatmap
# par(mfrow=c(1,1))
# #svglite(file ="CCL_pathway_netvisual_heatmap.svg")
# netVisual_heatmap(cellchat, signaling = pathways.show, color.heatmap = "Reds")
# #dev.off()
#
# #> Do heatmap based on a single object
# #ggsave('CCL_pathway_netvisual_heatmap.pdf')

# %%
# %%R
# netAnalysis_contribution(cellchat, signaling = pathways.show)
# #ggsave('CCL_pathway_contribution.pdf')

# %%
# %%R
# pairLR.CXCL <- extractEnrichedLR(cellchat, signaling = pathways.show, geneLR.return = FALSE)
# LR.show <- pairLR.CXCL[1,] # show one ligand-receptor pair
# # Hierarchy plot
# vertex.receiver = seq(1,4) # a numeric vector
# netVisual_individual(cellchat, signaling = pathways.show,  pairLR.use = LR.show, vertex.receiver = vertex.receiver)
# #> [[1]]
# # Circle plot
# #svglite(file ="CCL5_CCR1.svg")
# netVisual_individual(cellchat, signaling = pathways.show, pairLR.use = LR.show, layout = "circle")
# #dev.off()
#
# #ggsave('CCL5_CCR1.pdf')
# Out:
# [[1]]

# %%
# %%R
# #svglite(file ="CCL5_CCR1_chord.svg")
# netVisual_individual(cellchat, signaling = pathways.show, pairLR.use = LR.show, layout = "chord")
# #dev.off()
#
# #ggsave('CCL5_CCR1_chord.pdf')
# Out:
# [[1]]

# %%
# %%R
# netVisual_bubble(cellchat, sources.use = c(2,3), signaling = c("CCL"), remove.isolate = FALSE)
# ggsave('ccl_nk_cells_bubble.pdf')
# Out:
# Saving 6.67 x 6.67 in image

# %%
# %%R
# plotGeneExpression(cellchat, signaling = "CCL")
# ggsave('CCL_gene_expression.pdf')
# Out:
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Saving 6.67 x 6.67 in image

# %%
# %%R
# # Compute the network centrality scores
# cellchat <- netAnalysis_computeCentrality(cellchat, slot.name = "netP") # the slot 'netP' means the inferred intercellular communication network of signaling pathways
# # Visualize the computed centrality scores using heatmap, allowing ready identification of major signaling roles of cell groups
# svglite(file ="CCL_sig_pathway_role_network.svg")
# netAnalysis_signalingRole_network(cellchat, signaling = pathways.show, width = 8, height = 2.5, font.size = 10)
# dev.off()
#
# #ggsave('CCL_sig_pathway_role_network.pdf')
# Out:
#   |                                                  | 0 % ~calculating   |++                                                | 2 % ~01s           |+++                                               | 5 % ~03s           |++++                                              | 7 % ~03s           |+++++                                             | 9 % ~02s           |++++++                                            | 11% ~03s           |+++++++                                           | 14% ~02s           |++++++++                                          | 16% ~02s           |++++++++++                                        | 18% ~02s           |+++++++++++                                       | 20% ~02s           |++++++++++++                                      | 23% ~02s           |+++++++++++++                                     | 25% ~02s           |++++++++++++++                                    | 27% ~01s           |+++++++++++++++                                   | 30% ~01s           |++++++++++++++++                                  | 32% ~01s           |++++++++++++++++++                                | 34% ~01s           |+++++++++++++++++++                               | 36% ~01s           |++++++++++++++++++++                              | 39% ~01s           |+++++++++++++++++++++                             | 41% ~01s           |++++++++++++++++++++++                            | 43% ~01s           |+++++++++++++++++++++++                           | 45% ~01s           |++++++++++++++++++++++++                          | 48% ~01s           |+++++++++++++++++++++++++                         | 50% ~01s           |+++++++++++++++++++++++++++                       | 52% ~01s           |++++++++++++++++++++++++++++                      | 55% ~01s           |+++++++++++++++++++++++++++++                     | 57% ~01s           |++++++++++++++++++++++++++++++                    | 59% ~01s           |+++++++++++++++++++++++++++++++                   | 61% ~01s           |++++++++++++++++++++++++++++++++                  | 64% ~01s           |+++++++++++++++++++++++++++++++++                 | 66% ~01s           |+++++++++++++++++++++++++++++++++++               | 68% ~00s           |++++++++++++++++++++++++++++++++++++              | 70% ~00s           |+++++++++++++++++++++++++++++++++++++             | 73% ~00s           |++++++++++++++++++++++++++++++++++++++            | 75% ~00s           |+++++++++++++++++++++++++++++++++++++++           | 77% ~00s           |++++++++++++++++++++++++++++++++++++++++          | 80% ~00s           |+++++++++++++++++++++++++++++++++++++++++         | 82% ~00s           |+++++++++++++++++++++++++++++++++++++++++++       | 84% ~00s           |++++++++++++++++++++++++++++++++++++++++++++      | 86% ~00s           |+++++++++++++++++++++++++++++++++++++++++++++     | 89% ~00s           |++++++++++++++++++++++++++++++++++++++++++++++    | 91% ~00s           |+++++++++++++++++++++++++++++++++++++++++++++++   | 93% ~00s           |++++++++++++++++++++++++++++++++++++++++++++++++  | 95% ~00s           |+++++++++++++++++++++++++++++++++++++++++++++++++ | 98% ~00s           |++++++++++++++++++++++++++++++++++++++++++++++++++| 100% elapsed=01s
# png
#   2

# %% [markdown]
# ### MHC-I

# %%
# %%R
# pathways.show <- c("MHC-I")
# # Hierarchy plot
# # Here we define `vertex.receive` so that the left portion of the hierarchy plot shows signaling to fibroblast and the right portion shows signaling to immune cells
# vertex.receiver = seq(1,4) # a numeric vector.
# #svglite(file ="a.pdf")
# netVisual_aggregate(cellchat, signaling = pathways.show,  vertex.receiver = vertex.receiver)
# # Circle plot
# #par(mfrow=c(1,1))
# #svglite(file ="MHC_I_pathway_netvisual_aggregate_circle.svg")
# netVisual_aggregate(cellchat, signaling = pathways.show, layout = "circle")
# #ggsave('MHC_I_pathway_netvisual_aggregate_circle.pdf')
# #dev.off()

# %%
# %%R
# # Chord diagram
# par(mfrow=c(1,1))
# #svglite(file ="MHC_I_pathway_netvisual_aggregate_chord.svg")
# netVisual_aggregate(cellchat, signaling = pathways.show, layout = "chord")
# #dev.off()
# #ggsave('MHC_I_pathway_netvisual_aggregate_chord.pdf')

# %%
# %%R
# # Heatmap
# par(mfrow=c(1,1))
# netVisual_heatmap(cellchat, signaling = pathways.show, color.heatmap = "Reds")
# #> Do heatmap based on a single object
# #ggsave('MHC_I_pathway_netvisual_heatmap.pdf')

# %%
# %%R
# netAnalysis_contribution(cellchat, signaling = pathways.show)#, return.data=TRUE)
# #ggsave('MHC_I_pathway_contribution.pdf')

# %%
# %%R
# mhc_cont$LR.contribution$name
# Out:
#  [1] HLA-E - CD94:NKG2A HLA-B - CD8A       HLA-A - CD8A       HLA-E - KLRC1
#  [5] HLA-C - CD8A       HLA-B - CD8B       HLA-A - CD8B       HLA-C - CD8B
#  [9] HLA-E - CD8A       HLA-E - CD8B       HLA-F - CD8A       HLA-F - CD8B
# 12 Levels: HLA-E - CD94:NKG2A HLA-B - CD8A HLA-A - CD8A ... HLA-F - CD8B

# %%
# %%R
# pairLR.CXCL <- extractEnrichedLR(cellchat, signaling = pathways.show, geneLR.return = FALSE)
# pairLR.CXCL
# Out:
#   interaction_name
# 1       HLA-A_CD8A
# 2       HLA-C_CD8A
# 3       HLA-E_CD8A
# 4       HLA-A_CD8B
# 5       HLA-C_CD8B
# 6       HLA-E_CD8B
# 7      HLA-E_KLRC1
# 8 HLA-E_CD94:NKG2A

# %%
# %%R
# pairLR.CXCL <- extractEnrichedLR(cellchat, signaling = pathways.show, geneLR.return = FALSE)
# LR.show <- pairLR.CXCL[7,] # show one ligand-receptor pair
# # Hierarchy plot
# vertex.receiver = seq(1,4) # a numeric vector
# netVisual_individual(cellchat, signaling = pathways.show,  pairLR.use = LR.show, vertex.receiver = vertex.receiver)
# #> [[1]]
# # Circle plot
# #svglite(file ="HLA_E_KLRC1.svg")
# netVisual_individual(cellchat, signaling = pathways.show, pairLR.use = LR.show, layout = "circle")
# #dev.off()
# #ggsave('HLA_E_KLRC1.pdf')
# Out:
# [[1]]

# %%
# %%R
# pairLR.CXCL <- extractEnrichedLR(cellchat, signaling = pathways.show, geneLR.return = FALSE)
# LR.show <- pairLR.CXCL[8,] # show one ligand-receptor pair
# # Hierarchy plot
# vertex.receiver = seq(1,4) # a numeric vector
# netVisual_individual(cellchat, signaling = pathways.show,  pairLR.use = LR.show, vertex.receiver = vertex.receiver)
# #> [[1]]
# # Circle plot
# #svglite(file ="HLA_E_CD94.svg")
# netVisual_individual(cellchat, signaling = pathways.show, pairLR.use = LR.show, layout = "circle")
# #dev.off()
# #ggsave('HLA_E_CD94.pdf')
# Out:
# [[1]]

# %%
# %%R
# svglite(file ="HLA_E_CD94_chord.svg")
# netVisual_individual(cellchat, signaling = pathways.show, pairLR.use = LR.show, layout = "chord")
# dev.off()
# #ggsave('HLA_E_CD94.pdf')
# Out:
# png
#   2

# %%
# %%R
# netVisual_bubble(cellchat, targets.use = c(2,3), signaling = c("MHC-I"), remove.isolate = FALSE)
# #ggsave('MHC_I_nk_cells_bubble.pdf')

# %%
# %%R
# plotGeneExpression(cellchat, signaling = "MHC-I")
# ggsave('MHC_I_gene_expression.pdf')
# Out:
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Saving 6.67 x 6.67 in image

# %%
# %%R
# # Compute the network centrality scores
# cellchat <- netAnalysis_computeCentrality(cellchat, slot.name = "netP") # the slot 'netP' means the inferred intercellular communication network of signaling pathways
# # Visualize the computed centrality scores using heatmap, allowing ready identification of major signaling roles of cell groups
# svglite(file ="MHC_I_sig_pathway_role_network.svg")
# netAnalysis_signalingRole_network(cellchat, signaling = pathways.show, width = 8, height = 2.5, font.size = 10)
# dev.off()
# #ggsave('MHC_I_sig_pathway_role_network.pdf')
# Out:
#   |                                                  | 0 % ~calculating   |++                                                | 2 % ~02s           |+++                                               | 5 % ~04s           |++++                                              | 7 % ~03s           |+++++                                             | 9 % ~03s           |++++++                                            | 11% ~03s           |+++++++                                           | 14% ~03s           |++++++++                                          | 16% ~03s           |++++++++++                                        | 18% ~02s           |+++++++++++                                       | 20% ~02s           |++++++++++++                                      | 23% ~02s           |+++++++++++++                                     | 25% ~02s           |++++++++++++++                                    | 27% ~02s           |+++++++++++++++                                   | 30% ~02s           |++++++++++++++++                                  | 32% ~02s           |++++++++++++++++++                                | 34% ~01s           |+++++++++++++++++++                               | 36% ~01s           |++++++++++++++++++++                              | 39% ~01s           |+++++++++++++++++++++                             | 41% ~01s           |++++++++++++++++++++++                            | 43% ~01s           |+++++++++++++++++++++++                           | 45% ~01s           |++++++++++++++++++++++++                          | 48% ~01s           |+++++++++++++++++++++++++                         | 50% ~01s           |+++++++++++++++++++++++++++                       | 52% ~01s           |++++++++++++++++++++++++++++                      | 55% ~01s           |+++++++++++++++++++++++++++++                     | 57% ~01s           |++++++++++++++++++++++++++++++                    | 59% ~01s           |+++++++++++++++++++++++++++++++                   | 61% ~01s           |++++++++++++++++++++++++++++++++                  | 64% ~01s           |+++++++++++++++++++++++++++++++++                 | 66% ~01s           |+++++++++++++++++++++++++++++++++++               | 68% ~01s           |++++++++++++++++++++++++++++++++++++              | 70% ~00s           |+++++++++++++++++++++++++++++++++++++             | 73% ~00s           |++++++++++++++++++++++++++++++++++++++            | 75% ~00s           |+++++++++++++++++++++++++++++++++++++++           | 77% ~00s           |++++++++++++++++++++++++++++++++++++++++          | 80% ~00s           |+++++++++++++++++++++++++++++++++++++++++         | 82% ~00s           |+++++++++++++++++++++++++++++++++++++++++++       | 84% ~00s           |++++++++++++++++++++++++++++++++++++++++++++      | 86% ~00s           |+++++++++++++++++++++++++++++++++++++++++++++     | 89% ~00s           |++++++++++++++++++++++++++++++++++++++++++++++    | 91% ~00s           |+++++++++++++++++++++++++++++++++++++++++++++++   | 93% ~00s           |++++++++++++++++++++++++++++++++++++++++++++++++  | 95% ~00s           |+++++++++++++++++++++++++++++++++++++++++++++++++ | 98% ~00s           |++++++++++++++++++++++++++++++++++++++++++++++++++| 100% elapsed=01s
# png
#   2

# %% [markdown]
# ### XCR

# %%
# %%R
# cellchat
# Out:
# An object of class CellChat created from a single dataset
#  26355 genes.
#  782101 cells.
# CellChat analysis of single cell RNA-seq data!

# %%
# %%R
# pathways.show.all <- cellchat@netP$pathways

# %%
# %%R
# pathways.show.all
# Out:
#  [1] "MIF"        "MHC-I"      "SPP1"       "COLLAGEN"   "PTN"
#  [6] "CLEC"       "APP"        "MHC-II"     "FN1"        "GALECTIN"
# [11] "LAMININ"    "ANNEXIN"    "MK"         "PSAP"       "ITGB2"
# [16] "VISFATIN"   "COMPLEMENT" "ADGRE5"     "GRN"        "CD45"
# [21] "ICAM"       "NCAM"       "CXCL"       "IL1"        "EGF"
# [26] "LCK"        "CD22"       "VEGF"       "THY1"       "JAM"
# [31] "SELPLG"     "CCL"        "SELL"       "THBS"       "PARs"
# [36] "PECAM1"     "CLDN"       "CADM"       "MAG"        "FGF"
# [41] "TGFb"       "CD86"       "IL16"       "CD39"       "ESAM"
# [46] "GAS"        "CNTN"       "RESISTIN"   "ALCAM"      "CD6"
# [51] "CDH"        "ANGPTL"     "ANXA1"      "ANGPT"      "NECTIN"
# [56] "BAFF"       "NOTCH"      "EDN"        "CD46"       "SEMA4"
# [61] "OSM"        "SEMA3"      "CSF"        "TIGIT"      "PDGF"
# [66] "VISTA"      "CALCR"      "CD40"       "CD96"       "MPZ"
# [71] "CDH5"       "TWEAK"      "SEMA7"      "LIGHT"      "HSPG"
# [76] "LIFR"       "NRXN"       "SEMA6"      "AGRN"       "ICOS"
# [81] "PROS"       "TENASCIN"   "BMP"        "FLT3"       "FASLG"
# [86] "NGL"        "PTPRM"      "OCLN"

# %%
# %%R
# pathways.show <- c("NCAM")
# # Hierarchy plot
# # Here we define `vertex.receive` so that the left portion of the hierarchy plot shows signaling to fibroblast and the right portion shows signaling to immune cells
# vertex.receiver = seq(1,4) # a numeric vector.
# #svglite(file ="a.pdf")
# netVisual_aggregate(cellchat, signaling = pathways.show,  vertex.receiver = vertex.receiver)
# # Circle plot
# #par(mfrow=c(1,1))
# #svglite(file ="MHC_I_pathway_netvisual_aggregate_circle.svg")
# netVisual_aggregate(cellchat, signaling = pathways.show, layout = "circle")
# #ggsave('MHC_I_pathway_netvisual_aggregate_circle.pdf')
# #dev.off()

# %%
# %%R
# netAnalysis_contribution(cellchat, signaling = pathways.show)#, return.data=TRUE)
# #ggsave('MHC_I_pathway_contribution.pdf')

# %%
# %%R
# plotGeneExpression(cellchat, signaling = pathways.show)
# #ggsave('MHC_I_gene_expression.pdf')
# Out:
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
# Scale for y is already present.
# Adding another scale for y, which will replace the existing scale.
